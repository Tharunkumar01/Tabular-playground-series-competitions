# %% [markdown]
# <h2 style=color:green align='left'> Table of Contents </h2>
#
# ##### 1) Load Required Libraries
# ##### 2) Read Data
# ##### 3) EDA (Exploratory Data Analysis)
#
# >    3.1) Drop Unwanted Columns
#
# >    3.2) Missing Values
#
# >    3.3) Variable Analysis
#
# >    3.4) Outliers
#
# >    3.5) Relation between Features
#
# >    3.6) Skewness and Kurtosis
#
# ##### 4) Model Building and Evaluation
#
# >    4.1) XGBoost
#
# >    4.2) LightAutoML

# %% [markdown]
# <h1 style="background-color:LimeGreen; font-family:newtimeroman; font-size:200%; text-align:center; border-radius: 15px 50px;"> 1) Load Required Libraries </h1>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

plt.style.use("fivethirtyeight")
sns.set_style("darkgrid")

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, auc, roc_curve, roc_auc_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import LabelEncoder
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# <h1 style="background-color:LimeGreen; font-family:newtimeroman; font-size:200%; text-align:center; border-radius: 15px 50px;"> 2) Read Data </h1>

# %%
train = pd.read_csv("/kaggle/input/tabular-playground-series-may-2021/train.csv")
test = pd.read_csv("/kaggle/input/tabular-playground-series-may-2021/test.csv")
sub = pd.read_csv("/kaggle/input/tabular-playground-series-may-2021/sample_submission.csv")

all_df = pd.concat([train, test], axis=0)
all_df = all_df.drop(['id', 'target'], axis=1)

# %%
lbe = LabelEncoder()
train['target'] = lbe.fit_transform(train['target'])

le = LabelEncoder()
for col in all_df.columns:
    all_df[col] = le.fit_transform(all_df[col])

for col in all_df.columns:
    all_df[col] = np.log1p(all_df[col])

# %%
train_df = all_df[:len(train)]
train_df['target'] = train['target']
test_df = all_df[len(train):]

# %% [markdown]
# <h1 style="background-color:LimeGreen; font-family:newtimeroman; font-size:200%; text-align:center; border-radius: 15px 50px;"> 4) Model Building and Evaluation </h1>

# %%
# Independant variable
X = train_df.drop('target', axis=1)

# Dependant variable
y = train_df['target']

# %%
# split  data into training and testing sets of 80:20 ratio
# 20% of test size selected
# random_state is random seed
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print("Length of X_train is: {X_train}".format(X_train = len(X_train)))
print("Length of X_test is: {X_test}".format(X_test = len(X_test)))
print("Length of y_train is: {y_train}".format(y_train = len(y_train)))
print("Length of y_test is: {y_test}".format(y_test = len(y_test)))
# Out:
# Length of X_train is: 80000
# Length of X_test is: 20000
# Length of y_train is: 80000
# Length of y_test is: 20000

# %% [markdown]
# <h1 style="background-color:orange; font-family:newtimeroman; font-size:160%; text-align:left;"> 4.1) XGBoost </h1>

# %%
xgb = XGBClassifier(random_state=42, use_label_encoder=True)
xgb = xgb.fit(X, y)
# Out:
# [16:44:03] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_pred_xgb = xgb.predict_proba(X_test)

# %%
y_pred_xgb_test = xgb.predict_proba(test)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-11-07137deb1062> in <module>
# ----> 1 y_pred_xgb_test = xgb.predict_proba(test)
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict_proba(self, X, ntree_limit, validate_features, base_margin, iteration_range)
#    1277             validate_features=validate_features,
#    1278             base_margin=base_margin,
# -> 1279             iteration_range=iteration_range
#    1280         )
#    1281         # If model is loaded from a raw booster there's no `n_classes_`
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     824                     missing=self.missing,
#     825                     base_margin=base_margin,
# --> 826                     validate_features=validate_features,
#     827                 )
#     828                 if _is_cupy_array(predts):
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    1852                     ctypes.byref(shape),
#    1853                     ctypes.byref(dims),
# -> 1854                     ctypes.byref(preds),
#    1855                 )
#    1856             )
#
# /opt/conda/lib/python3.7/site-packages/xgboost/core.py in _check_call(ret)
#     208     """
#     209     if ret != 0:
# --> 210         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     211
#     212
#
# XGBoostError: [16:44:42] ../src/predictor/cpu_predictor.cc:258: Check failed: m->NumColumns() == model.learner_model_param->num_feature (51 vs. 50) : Number of columns in data must equal to trained model.
# Stack trace:
#   [bt] (0) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x912df) [0x7fc3707582df]
#   [bt] (1) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x243048) [0x7fc37090a048]
#   [bt] (2) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x244d3d) [0x7fc37090bd3d]
#   [bt] (3) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x198221) [0x7fc37085f221]
#   [bt] (4) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x1ce6a7) [0x7fc3708956a7]
#   [bt] (5) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(+0x9cb2e) [0x7fc370763b2e]
#   [bt] (6) /opt/conda/lib/python3.7/site-packages/xgboost/lib/libxgboost.so(XGBoosterPredictFromDense+0x225) [0x7fc37074afa5]
#   [bt] (7) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.7(+0x69dd) [0x7fc3eb0b09dd]
#   [bt] (8) /opt/conda/lib/python3.7/lib-dynload/../../libffi.so.7(+0x6067) [0x7fc3eb0b0067]

# %% [markdown]
# <h1 style="background-color:orange; font-family:newtimeroman; font-size:160%; text-align:left;"> 4.2) LightAutoML </h1>

# %%
pip install -U lightautoml
# Out:
# Collecting lightautoml
#   Downloading LightAutoML-0.2.13-py3-none-any.whl (250 kB)
#      |████████████████████████████████| 250 kB 1.2 MB/s
# Requirement already satisfied: networkx in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.5)
# Requirement already satisfied: pywavelets in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.1.1)
# Requirement already satisfied: albumentations>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.2)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1.48)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.1)
# Collecting importlib-metadata<2.0,>=1.0
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.24.1)
# Requirement already satisfied: transformers>=4 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.5.1)
# Requirement already satisfied: catboost in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.25.1)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.0.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from lightautoml) (4.59.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.19.5)
# Collecting json2html
#   Downloading json2html-1.3.0.tar.gz (7.0 kB)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.5.1)
# Requirement already satisfied: pandas>=1 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.2.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.5.4)
# Requirement already satisfied: cmaes in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.8.2)
# Collecting autowoe>=1.2
#   Downloading AutoWoE-1.2.5-py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 5.5 MB/s
# Collecting lightgbm<3.0,>=2.3
#   Downloading lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.0 MB/s
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.18.1)
# Collecting log-calls
#   Downloading log_calls-0.3.2.tar.gz (232 kB)
#      |████████████████████████████████| 232 kB 6.4 MB/s
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.0.1)
# Collecting poetry-core<2.0.0,>=1.0.0
#   Downloading poetry_core-1.0.3-py2.py3-none-any.whl (424 kB)
#      |████████████████████████████████| 424 kB 6.2 MB/s
# Collecting efficientnet-pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.7.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from lightautoml) (5.3.1)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.7/site-packages (from lightautoml) (0.11.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from lightautoml) (3.2.4)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (1.7.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from lightautoml) (2.11.3)
# Requirement already satisfied: imgaug>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (0.4.0)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from albumentations>=0.4.6->lightautoml) (4.5.1.48)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (3.4.1)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (0.2.4)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (6.2.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from autowoe>=1.2->lightautoml) (2021.1)
# Collecting sphinx
#   Downloading Sphinx-3.5.4-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 6.5 MB/s
# Requirement already satisfied: Shapely in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.7.1)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (2.9.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (7.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations>=0.4.6->lightautoml) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata<2.0,>=1.0->lightautoml) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1->lightautoml) (2.8.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image->lightautoml) (2021.4.8)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe>=1.2->lightautoml) (0.10.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx->lightautoml) (4.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->lightautoml) (2.1.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.6->lightautoml) (0.6)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.10.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (20.9)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2.25.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (2021.3.17)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers>=4->lightautoml) (0.0.45)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (4.14.3)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (from catboost->lightautoml) (0.8.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.7/site-packages (from gensim->lightautoml) (5.0.0)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (0.2.1)
# Requirement already satisfied: convertdate>=2.3.0 in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.3.2)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.7/site-packages (from holidays->lightautoml) (2.1.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.7/site-packages (from convertdate>=2.3.0->holidays->lightautoml) (0.5.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->lightautoml) (1.1.1)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.5.8)
# Requirement already satisfied: cliff in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (3.7.0)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (5.0.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from optuna->lightautoml) (1.4.3)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.7/site-packages (from sqlalchemy>=1.1.0->optuna->lightautoml) (1.0.0)
# Requirement already satisfied: python-editor>=0.3 in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.0.4)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.7/site-packages (from alembic->optuna->lightautoml) (1.1.4)
# Requirement already satisfied: PrettyTable>=0.7.2 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (2.1.0)
# Requirement already satisfied: stevedore>=2.0.1 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (1.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from cliff->optuna->lightautoml) (5.5.1)
# Requirement already satisfied: colorama>=0.3.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.4.4)
# Requirement already satisfied: attrs>=16.3.0 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (20.3.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /opt/conda/lib/python3.7/site-packages (from cmd2>=1.0.0->cliff->optuna->lightautoml) (1.8.2)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly->catboost->lightautoml) (1.3.3)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.13.1)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.1.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (0.10.2)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe>=1.2->lightautoml) (1.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers>=4->lightautoml) (4.0.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers>=4->lightautoml) (7.1.2)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 10.0 MB/s
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-1.0.3-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 2.7 MB/s
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 3.8 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (49.6.0.post20210108)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 1.5 MB/s
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.4-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 3.6 MB/s
# Collecting docutils<0.17,>=0.12
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 10.1 MB/s
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.8.1)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe>=1.2->lightautoml) (2.9.0)
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.0 MB/s
# Building wheels for collected packages: efficientnet-pytorch, json2html, log-calls
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=3250dc617e11e2bfda84c84adb1caba56bfaab776b4a36415e83923ca115f2e0
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7595 sha256=4e43c1f28d8c9953ac855ecfef7d8deebb1bea566985fc9cbba06bd092c5553d
#   Stored in directory: /root/.cache/pip/wheels/e5/99/37/e1839a5ad733e0d6abb7e0419fd913e8926ddf96408239ce01
# done
#   Created wheel for log-calls: filename=log_calls-0.3.2-py3-none-any.whl size=51828 sha256=0cae0cb1b765d0cffd449b7b1dd1c9127bc9bb7023d48ef9c433f925287215b2
#   Stored in directory: /root/.cache/pip/wheels/4c/4b/a5/a5643cfdcff002bbaf88cff0e52326db94182507613b53e971
# Successfully built efficientnet-pytorch json2html log-calls
# Installing collected packages: importlib-metadata, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, imagesize, docutils, alabaster, sphinx, lightgbm, poetry-core, log-calls, json2html, efficientnet-pytorch, autowoe, lightautoml
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.4.0
#     Uninstalling importlib-metadata-3.4.0:
#       Successfully uninstalled importlib-metadata-3.4.0
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.2.0
#     Uninstalling lightgbm-3.2.0:
#       Successfully uninstalled lightgbm-3.2.0
# Successfully installed alabaster-0.7.12 autowoe-1.2.5 docutils-0.16 efficientnet-pytorch-0.7.1 imagesize-1.2.0 importlib-metadata-1.7.0 json2html-1.3.0 lightautoml-0.2.13 lightgbm-2.3.1 log-calls-0.3.2 poetry-core-1.0.3 snowballstemmer-2.1.0 sphinx-3.5.4 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-1.0.3 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports from our package
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task
from sklearn.metrics import log_loss

# %%
N_THREADS = 4 # threads cnt for lgbm and linear models
N_FOLDS = 5 # folds cnt for AutoML
RANDOM_STATE = 2021 # fixed random state for various reasons
TEST_SIZE = 0.2 # Test size for metric check
TIMEOUT = 14400 # Time in seconds for automl run

# %%
# %%time

automl = TabularUtilizedAutoML(task = Task('multiclass',), 
                               timeout = TIMEOUT,
                               cpu_limit = N_THREADS,
                               reader_params = {'n_jobs': N_THREADS},
                               tuning_params = {'max_tuning_iter': 20, 'max_tuning_time': 50},
                               
)
# Out:
# CPU times: user 28.2 ms, sys: 1.02 ms, total: 29.2 ms
# Wall time: 28 ms

# %%
target_column = 'target'

roles = {
    'target': target_column
}

lightml_pred = automl.fit_predict(train_df, roles = roles)
print('lightml_pred:\n{}\nShape = {}'.format(lightml_pred[:10], lightml_pred.shape))
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'random_state': 42}
# Start automl preset with listed constraints:
# - time: 14399.996123075485 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (100000, 51)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 14357.884085178375 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1102790553703905
# Linear model: C = 5e-05 score = -1.104653170647472
# Linear model: C = 0.0001 score = -1.1038413102462887
# Linear model: C = 0.0005 score = -1.1037279969975353
# Linear model: C = 0.001 score = -1.1038292608886957
# Linear model: C = 0.005 score = -1.1038546926751733
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1094055499732494
# Linear model: C = 5e-05 score = -1.1023322695881128
# Linear model: C = 0.0001 score = -1.1008298567593098
# Linear model: C = 0.0005 score = -1.0998604953348636
# Linear model: C = 0.001 score = -1.0998341137476266
# Linear model: C = 0.005 score = -1.099916041493416
# Linear model: C = 0.01 score = -1.099916041493416
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1093924018234014
# Linear model: C = 5e-05 score = -1.1020151206344366
# Linear model: C = 0.0001 score = -1.1003068270914256
# Linear model: C = 0.0005 score = -1.0989058449305593
# Linear model: C = 0.001 score = -1.0987419034570456
# Linear model: C = 0.005 score = -1.0985823609121144
# Linear model: C = 0.01 score = -1.0985823609121144
# Linear model: C = 0.05 score = -1.0985823609121144
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.109807382683456
# Linear model: C = 5e-05 score = -1.1032228090792895
# Linear model: C = 0.0001 score = -1.1019249709606171
# Linear model: C = 0.0005 score = -1.1010216395661234
# Linear model: C = 0.001 score = -1.1009210442908108
# Linear model: C = 0.005 score = -1.1007665515452623
# Linear model: C = 0.01 score = -1.1007665515452623
# Linear model: C = 0.05 score = -1.1007665515452623
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1096464761033655
# Linear model: C = 5e-05 score = -1.102738811147213
# Linear model: C = 0.0001 score = -1.1013114993959665
# Linear model: C = 0.0005 score = -1.100308641473204
# Linear model: C = 0.001 score = -1.100173833336681
# Linear model: C = 0.005 score = -1.099868533539027
# Linear model: C = 0.01 score = -1.099868533539027
# Linear model: C = 0.05 score = -1.099868533539027
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 14331.786511421204
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09714
# [200]	valid's multi_logloss: 1.09588
# [300]	valid's multi_logloss: 1.09716
# Early stopping, best iteration is:
# [170]	valid's multi_logloss: 1.09569
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09605
# [200]	valid's multi_logloss: 1.09391
# [300]	valid's multi_logloss: 1.0947
# [400]	valid's multi_logloss: 1.0964
# Early stopping, best iteration is:
# [220]	valid's multi_logloss: 1.09382
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09462
# [200]	valid's multi_logloss: 1.09192
# [300]	valid's multi_logloss: 1.09224
# Early stopping, best iteration is:
# [196]	valid's multi_logloss: 1.09187
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09579
# [200]	valid's multi_logloss: 1.09366
# [300]	valid's multi_logloss: 1.09408
# [400]	valid's multi_logloss: 1.09555
# Early stopping, best iteration is:
# [221]	valid's multi_logloss: 1.09356
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.095
# [200]	valid's multi_logloss: 1.09275
# [300]	valid's multi_logloss: 1.09365
# [400]	valid's multi_logloss: 1.09496
# Early stopping, best iteration is:
# [210]	valid's multi_logloss: 1.0927
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 2739.4269222229427 secs
# Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09824
# [200]	valid's multi_logloss: 1.10207
# [300]	valid's multi_logloss: 1.10801
# Early stopping, best iteration is:
# [100]	valid's multi_logloss: 1.09824
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09795
# [200]	valid's multi_logloss: 1.09972
# [300]	valid's multi_logloss: 1.10363
# Early stopping, best iteration is:
# [118]	valid's multi_logloss: 1.09788
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10055
# Early stopping, best iteration is:
# [58]	valid's multi_logloss: 1.09882
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.0977
# Early stopping, best iteration is:
# [62]	valid's multi_logloss: 1.09604
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09662
# Early stopping, best iteration is:
# [80]	valid's multi_logloss: 1.09591
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09778
# Early stopping, best iteration is:
# [62]	valid's multi_logloss: 1.09634
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09675
# Early stopping, best iteration is:
# [64]	valid's multi_logloss: 1.09574
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3685782	test: 1.3686043	best: 1.3686043 (0)	total: 100ms	remaining: 5m 1s
# 100:	learn: 1.1078409	test: 1.1111473	best: 1.1111473 (100)	total: 4.66s	remaining: 2m 13s
# 200:	learn: 1.0974214	test: 1.1046612	best: 1.1046612 (200)	total: 9.33s	remaining: 2m 9s
# 300:	learn: 1.0910525	test: 1.1014334	best: 1.1014334 (300)	total: 13.3s	remaining: 1m 59s
# 400:	learn: 1.0856837	test: 1.0991766	best: 1.0991766 (400)	total: 17.4s	remaining: 1m 52s
# 500:	learn: 1.0801986	test: 1.0974164	best: 1.0974164 (500)	total: 21.5s	remaining: 1m 47s
# 600:	learn: 1.0754020	test: 1.0964062	best: 1.0964062 (600)	total: 25.5s	remaining: 1m 41s
# 700:	learn: 1.0711990	test: 1.0957257	best: 1.0957257 (700)	total: 29.8s	remaining: 1m 37s
# 800:	learn: 1.0673204	test: 1.0954704	best: 1.0954681 (791)	total: 33.8s	remaining: 1m 32s
# 900:	learn: 1.0635444	test: 1.0953132	best: 1.0952498 (875)	total: 37.6s	remaining: 1m 27s
# 1000:	learn: 1.0601109	test: 1.0951495	best: 1.0951495 (1000)	total: 41.5s	remaining: 1m 22s
# 1100:	learn: 1.0567671	test: 1.0949877	best: 1.0949843 (1098)	total: 45.4s	remaining: 1m 18s
# 1200:	learn: 1.0534349	test: 1.0950147	best: 1.0949791 (1103)	total: 49.2s	remaining: 1m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.094979149
# bestIteration = 1103
#
# Shrink model to first 1104 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3685814	test: 1.3686002	best: 1.3686002 (0)	total: 39.4ms	remaining: 1m 58s
# 100:	learn: 1.1085985	test: 1.1105620	best: 1.1105620 (100)	total: 3.84s	remaining: 1m 50s
# 200:	learn: 1.0981431	test: 1.1029635	best: 1.1029635 (200)	total: 8.14s	remaining: 1m 53s
# 300:	learn: 1.0919817	test: 1.0994770	best: 1.0994770 (300)	total: 12.4s	remaining: 1m 50s
# 400:	learn: 1.0865502	test: 1.0969741	best: 1.0969741 (400)	total: 16.4s	remaining: 1m 46s
# 500:	learn: 1.0810256	test: 1.0950196	best: 1.0950196 (500)	total: 20.4s	remaining: 1m 41s
# 600:	learn: 1.0764234	test: 1.0940170	best: 1.0940126 (599)	total: 24.3s	remaining: 1m 36s
# 700:	learn: 1.0721612	test: 1.0934587	best: 1.0934557 (699)	total: 28.3s	remaining: 1m 32s
# 800:	learn: 1.0683078	test: 1.0928989	best: 1.0928916 (799)	total: 32.3s	remaining: 1m 28s
# 900:	learn: 1.0646137	test: 1.0925267	best: 1.0925095 (888)	total: 36.2s	remaining: 1m 24s
# 1000:	learn: 1.0610975	test: 1.0922858	best: 1.0922654 (996)	total: 40.1s	remaining: 1m 20s
# 1100:	learn: 1.0577931	test: 1.0920735	best: 1.0920735 (1100)	total: 44.1s	remaining: 1m 16s
# 1200:	learn: 1.0546221	test: 1.0919762	best: 1.0919665 (1191)	total: 48.1s	remaining: 1m 12s
# 1300:	learn: 1.0513812	test: 1.0920665	best: 1.0919373 (1244)	total: 51.9s	remaining: 1m 7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091937323
# bestIteration = 1244
#
# Shrink model to first 1245 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3685814	test: 1.3685984	best: 1.3685984 (0)	total: 41.6ms	remaining: 2m 4s
# 100:	learn: 1.1086996	test: 1.1102152	best: 1.1102152 (100)	total: 3.79s	remaining: 1m 48s
# 200:	learn: 1.0985320	test: 1.1025762	best: 1.1025762 (200)	total: 8.13s	remaining: 1m 53s
# 300:	learn: 1.0925075	test: 1.0987576	best: 1.0987576 (300)	total: 12.1s	remaining: 1m 48s
# 400:	learn: 1.0870294	test: 1.0958862	best: 1.0958862 (400)	total: 16.1s	remaining: 1m 44s
# 500:	learn: 1.0816057	test: 1.0938187	best: 1.0938187 (500)	total: 20s	remaining: 1m 39s
# 600:	learn: 1.0769470	test: 1.0925378	best: 1.0925378 (600)	total: 24.2s	remaining: 1m 36s
# 700:	learn: 1.0726859	test: 1.0916771	best: 1.0916750 (698)	total: 28.1s	remaining: 1m 32s
# 800:	learn: 1.0688701	test: 1.0912335	best: 1.0912335 (800)	total: 31.9s	remaining: 1m 27s
# 900:	learn: 1.0652715	test: 1.0909494	best: 1.0909494 (900)	total: 35.8s	remaining: 1m 23s
# 1000:	learn: 1.0618202	test: 1.0906122	best: 1.0906028 (998)	total: 39.7s	remaining: 1m 19s
# 1100:	learn: 1.0584140	test: 1.0904454	best: 1.0904420 (1099)	total: 43.5s	remaining: 1m 14s
# 1200:	learn: 1.0551301	test: 1.0902566	best: 1.0902496 (1199)	total: 47.2s	remaining: 1m 10s
# 1300:	learn: 1.0519421	test: 1.0901408	best: 1.0901408 (1300)	total: 51.1s	remaining: 1m 6s
# 1400:	learn: 1.0487859	test: 1.0900690	best: 1.0900472 (1394)	total: 54.9s	remaining: 1m 2s
# 1500:	learn: 1.0458009	test: 1.0900632	best: 1.0900420 (1406)	total: 58.9s	remaining: 58.8s
# 1600:	learn: 1.0429145	test: 1.0900332	best: 1.0900299 (1598)	total: 1m 2s	remaining: 54.9s
# 1700:	learn: 1.0401187	test: 1.0899633	best: 1.0899507 (1672)	total: 1m 6s	remaining: 50.8s
# 1800:	learn: 1.0372953	test: 1.0899873	best: 1.0899470 (1771)	total: 1m 10s	remaining: 47s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.089947023
# bestIteration = 1771
#
# Shrink model to first 1772 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3685829	test: 1.3686007	best: 1.3686007 (0)	total: 38.3ms	remaining: 1m 54s
# 100:	learn: 1.1082387	test: 1.1107021	best: 1.1107021 (100)	total: 3.82s	remaining: 1m 49s
# 200:	learn: 1.0978603	test: 1.1036890	best: 1.1036890 (200)	total: 7.91s	remaining: 1m 50s
# 300:	learn: 1.0918049	test: 1.1003299	best: 1.1003299 (300)	total: 11.7s	remaining: 1m 45s
# 400:	learn: 1.0864806	test: 1.0979516	best: 1.0979516 (400)	total: 16s	remaining: 1m 43s
# 500:	learn: 1.0810768	test: 1.0959657	best: 1.0959657 (500)	total: 20s	remaining: 1m 39s
# 600:	learn: 1.0763024	test: 1.0948286	best: 1.0948286 (600)	total: 23.8s	remaining: 1m 35s
# 700:	learn: 1.0721190	test: 1.0940501	best: 1.0940501 (700)	total: 27.8s	remaining: 1m 31s
# 800:	learn: 1.0682223	test: 1.0935266	best: 1.0935093 (796)	total: 31.6s	remaining: 1m 26s
# 900:	learn: 1.0645909	test: 1.0930940	best: 1.0930940 (900)	total: 35.4s	remaining: 1m 22s
# 1000:	learn: 1.0611825	test: 1.0928637	best: 1.0928637 (1000)	total: 39.2s	remaining: 1m 18s
# 1100:	learn: 1.0578510	test: 1.0926459	best: 1.0926455 (1099)	total: 43s	remaining: 1m 14s
# 1200:	learn: 1.0546083	test: 1.0925105	best: 1.0925105 (1200)	total: 46.8s	remaining: 1m 10s
# 1300:	learn: 1.0514496	test: 1.0924585	best: 1.0924072 (1272)	total: 50.7s	remaining: 1m 6s
# 1400:	learn: 1.0483402	test: 1.0924824	best: 1.0924029 (1364)	total: 54.8s	remaining: 1m 2s
# 1500:	learn: 1.0452870	test: 1.0924134	best: 1.0923702 (1466)	total: 58.7s	remaining: 58.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092370184
# bestIteration = 1466
#
# Shrink model to first 1467 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3685795	test: 1.3685995	best: 1.3685995 (0)	total: 38.6ms	remaining: 1m 55s
# 100:	learn: 1.1087539	test: 1.1103911	best: 1.1103911 (100)	total: 3.8s	remaining: 1m 48s
# 200:	learn: 1.0983943	test: 1.1028500	best: 1.1028500 (200)	total: 7.74s	remaining: 1m 47s
# 300:	learn: 1.0921077	test: 1.0991995	best: 1.0991995 (300)	total: 11.5s	remaining: 1m 43s
# 400:	learn: 1.0867544	test: 1.0968279	best: 1.0968279 (400)	total: 15.6s	remaining: 1m 41s
# 500:	learn: 1.0814139	test: 1.0947845	best: 1.0947845 (500)	total: 19.7s	remaining: 1m 38s
# 600:	learn: 1.0767305	test: 1.0935311	best: 1.0935311 (600)	total: 23.9s	remaining: 1m 35s
# 700:	learn: 1.0724326	test: 1.0926702	best: 1.0926679 (699)	total: 27.8s	remaining: 1m 31s
# 800:	learn: 1.0686563	test: 1.0922169	best: 1.0922169 (800)	total: 31.7s	remaining: 1m 26s
# 900:	learn: 1.0649994	test: 1.0919188	best: 1.0918821 (886)	total: 35.6s	remaining: 1m 22s
# 1000:	learn: 1.0615966	test: 1.0917602	best: 1.0917602 (999)	total: 39.3s	remaining: 1m 18s
# 1100:	learn: 1.0581874	test: 1.0916092	best: 1.0915983 (1087)	total: 43.1s	remaining: 1m 14s
# 1200:	learn: 1.0548749	test: 1.0916302	best: 1.0915741 (1162)	total: 47s	remaining: 1m 10s
# 1300:	learn: 1.0516364	test: 1.0915670	best: 1.0915020 (1270)	total: 50.8s	remaining: 1m 6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091502007
# bestIteration = 1270
#
# Shrink model to first 1271 iterations.
# Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# Optuna may run 8937.835335084923 secs
# Start fitting Lvl_0_Pipe_1_Mod_3_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685846	test: 1.3685979	best: 1.3685979 (0)	total: 37.1ms	remaining: 1m 51s
# 100:	learn: 1.1101056	test: 1.1121223	best: 1.1121223 (100)	total: 3.94s	remaining: 1m 53s
# 200:	learn: 1.1012293	test: 1.1055931	best: 1.1055931 (200)	total: 7.7s	remaining: 1m 47s
# 300:	learn: 1.0960149	test: 1.1023939	best: 1.1023939 (300)	total: 11.3s	remaining: 1m 41s
# 400:	learn: 1.0918552	test: 1.1000793	best: 1.1000793 (400)	total: 15.1s	remaining: 1m 37s
# 500:	learn: 1.0879620	test: 1.0984473	best: 1.0984473 (500)	total: 18.7s	remaining: 1m 33s
# 600:	learn: 1.0845845	test: 1.0972300	best: 1.0972300 (600)	total: 22.3s	remaining: 1m 29s
# 700:	learn: 1.0816656	test: 1.0963633	best: 1.0963627 (699)	total: 25.9s	remaining: 1m 25s
# 800:	learn: 1.0790487	test: 1.0959388	best: 1.0959388 (800)	total: 29.5s	remaining: 1m 20s
# 900:	learn: 1.0765870	test: 1.0956041	best: 1.0956041 (900)	total: 33.1s	remaining: 1m 16s
# 1000:	learn: 1.0742777	test: 1.0953595	best: 1.0953579 (999)	total: 37s	remaining: 1m 13s
# 1100:	learn: 1.0720842	test: 1.0951971	best: 1.0951971 (1100)	total: 40.5s	remaining: 1m 9s
# 1200:	learn: 1.0699669	test: 1.0950922	best: 1.0950625 (1183)	total: 44s	remaining: 1m 5s
# 1300:	learn: 1.0680078	test: 1.0949299	best: 1.0949256 (1296)	total: 47.6s	remaining: 1m 2s
# 1400:	learn: 1.0660759	test: 1.0949026	best: 1.0948698 (1340)	total: 51.1s	remaining: 58.3s
# 1500:	learn: 1.0641436	test: 1.0948979	best: 1.0948403 (1421)	total: 54.6s	remaining: 54.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09484029
# bestIteration = 1421
#
# Shrink model to first 1422 iterations.
# Lvl_0_Pipe_1_Mod_3_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_3_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685846	test: 1.3685979	best: 1.3685979 (0)	total: 33.7ms	remaining: 1m 41s
# 100:	learn: 1.1101056	test: 1.1121223	best: 1.1121223 (100)	total: 3.61s	remaining: 1m 43s
# 200:	learn: 1.1012293	test: 1.1055931	best: 1.1055931 (200)	total: 7.37s	remaining: 1m 42s
# 300:	learn: 1.0960149	test: 1.1023939	best: 1.1023939 (300)	total: 11.4s	remaining: 1m 42s
# 400:	learn: 1.0918552	test: 1.1000793	best: 1.1000793 (400)	total: 15.3s	remaining: 1m 39s
# 500:	learn: 1.0879620	test: 1.0984473	best: 1.0984473 (500)	total: 19.1s	remaining: 1m 35s
# 600:	learn: 1.0845845	test: 1.0972300	best: 1.0972300 (600)	total: 22.7s	remaining: 1m 30s
# 700:	learn: 1.0816656	test: 1.0963633	best: 1.0963627 (699)	total: 26.3s	remaining: 1m 26s
# 800:	learn: 1.0790487	test: 1.0959388	best: 1.0959388 (800)	total: 29.9s	remaining: 1m 22s
# 900:	learn: 1.0765870	test: 1.0956041	best: 1.0956041 (900)	total: 33.6s	remaining: 1m 18s
# 1000:	learn: 1.0742777	test: 1.0953595	best: 1.0953579 (999)	total: 37.1s	remaining: 1m 14s
# 1100:	learn: 1.0720842	test: 1.0951971	best: 1.0951971 (1100)	total: 40.6s	remaining: 1m 9s
# 1200:	learn: 1.0699669	test: 1.0950922	best: 1.0950625 (1183)	total: 44.5s	remaining: 1m 6s
# 1300:	learn: 1.0680078	test: 1.0949299	best: 1.0949256 (1296)	total: 48s	remaining: 1m 2s
# 1400:	learn: 1.0660759	test: 1.0949026	best: 1.0948698 (1340)	total: 51.4s	remaining: 58.6s
# 1500:	learn: 1.0641436	test: 1.0948979	best: 1.0948403 (1421)	total: 54.8s	remaining: 54.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09484029
# bestIteration = 1421
#
# Shrink model to first 1422 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685861	test: 1.3685985	best: 1.3685985 (0)	total: 34.8ms	remaining: 1m 44s
# 100:	learn: 1.1105407	test: 1.1115731	best: 1.1115731 (100)	total: 3.5s	remaining: 1m 40s
# 200:	learn: 1.1018196	test: 1.1043308	best: 1.1043308 (200)	total: 7.24s	remaining: 1m 40s
# 300:	learn: 1.0965785	test: 1.1005953	best: 1.1005953 (300)	total: 10.9s	remaining: 1m 37s
# 400:	learn: 1.0922592	test: 1.0979998	best: 1.0979998 (400)	total: 14.6s	remaining: 1m 34s
# 500:	learn: 1.0883519	test: 1.0962584	best: 1.0962584 (500)	total: 18.5s	remaining: 1m 32s
# 600:	learn: 1.0851354	test: 1.0951180	best: 1.0951180 (600)	total: 22.2s	remaining: 1m 28s
# 700:	learn: 1.0822273	test: 1.0941971	best: 1.0941971 (700)	total: 25.8s	remaining: 1m 24s
# 800:	learn: 1.0796907	test: 1.0935077	best: 1.0935042 (798)	total: 29.3s	remaining: 1m 20s
# 900:	learn: 1.0771593	test: 1.0931036	best: 1.0930667 (893)	total: 32.9s	remaining: 1m 16s
# 1000:	learn: 1.0748204	test: 1.0928348	best: 1.0928342 (999)	total: 36.4s	remaining: 1m 12s
# 1100:	learn: 1.0725818	test: 1.0925707	best: 1.0925707 (1100)	total: 39.9s	remaining: 1m 8s
# 1200:	learn: 1.0705174	test: 1.0923025	best: 1.0923025 (1200)	total: 43.4s	remaining: 1m 5s
# 1300:	learn: 1.0685709	test: 1.0921310	best: 1.0921114 (1293)	total: 46.9s	remaining: 1m 1s
# 1400:	learn: 1.0665778	test: 1.0920594	best: 1.0920373 (1396)	total: 50.7s	remaining: 57.8s
# 1500:	learn: 1.0646959	test: 1.0920205	best: 1.0920003 (1460)	total: 54.2s	remaining: 54.2s
# 1600:	learn: 1.0628320	test: 1.0919687	best: 1.0919554 (1590)	total: 57.8s	remaining: 50.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091955443
# bestIteration = 1590
#
# Shrink model to first 1591 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685853	test: 1.3685968	best: 1.3685968 (0)	total: 36.6ms	remaining: 1m 49s
# 100:	learn: 1.1105969	test: 1.1114805	best: 1.1114805 (100)	total: 3.6s	remaining: 1m 43s
# 200:	learn: 1.1018819	test: 1.1039241	best: 1.1039241 (200)	total: 7.38s	remaining: 1m 42s
# 300:	learn: 1.0968741	test: 1.1001190	best: 1.1001190 (300)	total: 11s	remaining: 1m 38s
# 400:	learn: 1.0926745	test: 1.0973526	best: 1.0973526 (400)	total: 14.7s	remaining: 1m 35s
# 500:	learn: 1.0887884	test: 1.0951118	best: 1.0951118 (500)	total: 18.3s	remaining: 1m 31s
# 600:	learn: 1.0855093	test: 1.0937279	best: 1.0937279 (600)	total: 22.3s	remaining: 1m 28s
# 700:	learn: 1.0826799	test: 1.0927254	best: 1.0927254 (700)	total: 26s	remaining: 1m 25s
# 800:	learn: 1.0800876	test: 1.0921337	best: 1.0921337 (800)	total: 29.5s	remaining: 1m 20s
# 900:	learn: 1.0776350	test: 1.0916386	best: 1.0916256 (898)	total: 33s	remaining: 1m 16s
# 1000:	learn: 1.0753659	test: 1.0911647	best: 1.0911620 (999)	total: 36.6s	remaining: 1m 13s
# 1100:	learn: 1.0732057	test: 1.0908852	best: 1.0908846 (1098)	total: 40.2s	remaining: 1m 9s
# 1200:	learn: 1.0710844	test: 1.0906141	best: 1.0906120 (1199)	total: 43.7s	remaining: 1m 5s
# 1300:	learn: 1.0690652	test: 1.0904700	best: 1.0904555 (1290)	total: 47.3s	remaining: 1m 1s
# 1400:	learn: 1.0671484	test: 1.0903542	best: 1.0903489 (1398)	total: 50.7s	remaining: 57.9s
# 1500:	learn: 1.0652247	test: 1.0902905	best: 1.0902905 (1500)	total: 54.5s	remaining: 54.4s
# 1600:	learn: 1.0633509	test: 1.0901933	best: 1.0901933 (1600)	total: 58s	remaining: 50.7s
# 1700:	learn: 1.0615447	test: 1.0900669	best: 1.0900602 (1699)	total: 1m 1s	remaining: 47.1s
# 1800:	learn: 1.0597768	test: 1.0900350	best: 1.0900146 (1781)	total: 1m 5s	remaining: 43.4s
# 1900:	learn: 1.0580664	test: 1.0900453	best: 1.0900053 (1810)	total: 1m 8s	remaining: 39.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.090005277
# bestIteration = 1810
#
# Shrink model to first 1811 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685887	test: 1.3685942	best: 1.3685942 (0)	total: 35.5ms	remaining: 1m 46s
# 100:	learn: 1.1102109	test: 1.1119460	best: 1.1119460 (100)	total: 3.47s	remaining: 1m 39s
# 200:	learn: 1.1014314	test: 1.1050749	best: 1.1050749 (200)	total: 7.13s	remaining: 1m 39s
# 300:	learn: 1.0963978	test: 1.1015574	best: 1.1015574 (300)	total: 10.8s	remaining: 1m 36s
# 400:	learn: 1.0922467	test: 1.0988661	best: 1.0988661 (400)	total: 14.3s	remaining: 1m 32s
# 500:	learn: 1.0883744	test: 1.0967881	best: 1.0967881 (500)	total: 18.3s	remaining: 1m 31s
# 600:	learn: 1.0850501	test: 1.0955295	best: 1.0955295 (600)	total: 22s	remaining: 1m 27s
# 700:	learn: 1.0823063	test: 1.0946115	best: 1.0946057 (699)	total: 25.5s	remaining: 1m 23s
# 800:	learn: 1.0797321	test: 1.0940425	best: 1.0940357 (797)	total: 29s	remaining: 1m 19s
# 900:	learn: 1.0773213	test: 1.0935418	best: 1.0935418 (900)	total: 32.5s	remaining: 1m 15s
# 1000:	learn: 1.0750200	test: 1.0931676	best: 1.0931615 (998)	total: 36s	remaining: 1m 11s
# 1100:	learn: 1.0728672	test: 1.0927998	best: 1.0927998 (1100)	total: 39.4s	remaining: 1m 7s
# 1200:	learn: 1.0707244	test: 1.0924921	best: 1.0924886 (1197)	total: 42.9s	remaining: 1m 4s
# 1300:	learn: 1.0686598	test: 1.0923370	best: 1.0923345 (1299)	total: 46.4s	remaining: 1m
# 1400:	learn: 1.0666298	test: 1.0922459	best: 1.0922386 (1394)	total: 50.4s	remaining: 57.6s
# 1500:	learn: 1.0647707	test: 1.0921529	best: 1.0921330 (1488)	total: 53.9s	remaining: 53.9s
# 1600:	learn: 1.0629435	test: 1.0920181	best: 1.0920181 (1600)	total: 57.7s	remaining: 50.4s
# 1700:	learn: 1.0611792	test: 1.0919790	best: 1.0919782 (1695)	total: 1m 1s	remaining: 46.7s
# 1800:	learn: 1.0594338	test: 1.0919515	best: 1.0919427 (1798)	total: 1m 4s	remaining: 43s
# 1900:	learn: 1.0577520	test: 1.0919550	best: 1.0919292 (1840)	total: 1m 8s	remaining: 39.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091929199
# bestIteration = 1840
#
# Shrink model to first 1841 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685835	test: 1.3685957	best: 1.3685957 (0)	total: 34.4ms	remaining: 1m 43s
# 100:	learn: 1.1104273	test: 1.1111547	best: 1.1111547 (100)	total: 3.5s	remaining: 1m 40s
# 200:	learn: 1.1018286	test: 1.1040847	best: 1.1040847 (200)	total: 7.26s	remaining: 1m 41s
# 300:	learn: 1.0967604	test: 1.1003990	best: 1.1003990 (300)	total: 11.2s	remaining: 1m 40s
# 400:	learn: 1.0926902	test: 1.0978076	best: 1.0978076 (400)	total: 14.9s	remaining: 1m 36s
# 500:	learn: 1.0888262	test: 1.0958266	best: 1.0958266 (500)	total: 18.6s	remaining: 1m 32s
# 600:	learn: 1.0855680	test: 1.0944392	best: 1.0944392 (600)	total: 22.1s	remaining: 1m 28s
# 700:	learn: 1.0826880	test: 1.0934895	best: 1.0934800 (698)	total: 25.6s	remaining: 1m 24s
# 800:	learn: 1.0800968	test: 1.0928272	best: 1.0928272 (800)	total: 29.2s	remaining: 1m 20s
# 900:	learn: 1.0776655	test: 1.0923027	best: 1.0923027 (896)	total: 32.7s	remaining: 1m 16s
# 1000:	learn: 1.0753834	test: 1.0920899	best: 1.0920899 (1000)	total: 36.2s	remaining: 1m 12s
# 1100:	learn: 1.0731462	test: 1.0917646	best: 1.0917646 (1100)	total: 39.8s	remaining: 1m 8s
# 1200:	learn: 1.0710563	test: 1.0914599	best: 1.0914595 (1198)	total: 43.7s	remaining: 1m 5s
# 1300:	learn: 1.0690662	test: 1.0912543	best: 1.0912543 (1300)	total: 47.3s	remaining: 1m 1s
# 1400:	learn: 1.0671008	test: 1.0911000	best: 1.0910908 (1397)	total: 50.8s	remaining: 58s
# 1500:	learn: 1.0652688	test: 1.0910649	best: 1.0910254 (1451)	total: 54.3s	remaining: 54.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.0910254
# bestIteration = 1451
#
# Shrink model to first 1452 iterations.
# Lvl_0_Pipe_1_Mod_3_CatBoost fitting and predicting completed
# Time left 13394.663016080856
# Layer 1 training completed.
#
#
# Layer 2 ...
# Train process start. Time left 13394.572094202042 secs
# Start fitting Lvl_1_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0959236235931515
# Linear model: C = 5e-05 score = -1.0945453909739853
# Linear model: C = 0.0001 score = -1.0943936257220805
# Linear model: C = 0.0005 score = -1.0937504936166107
# Linear model: C = 0.001 score = -1.0933232481978834
# Linear model: C = 0.005 score = -1.09214185808748
# Linear model: C = 0.01 score = -1.09214185808748
# Linear model: C = 0.05 score = -1.092142659433186
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0928569387055933
# Linear model: C = 5e-05 score = -1.090851752086729
# Linear model: C = 0.0001 score = -1.0906875683262944
# Linear model: C = 0.0005 score = -1.0900840150520206
# Linear model: C = 0.001 score = -1.08963913724944
# Linear model: C = 0.005 score = -1.0883539567984641
# Linear model: C = 0.01 score = -1.0883539567984641
# Linear model: C = 0.05 score = -1.087675560387224
# Linear model: C = 0.1 score = -1.087675560387224
# Linear model: C = 0.5 score = -1.087675560387224
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0923212431818248
# Linear model: C = 5e-05 score = -1.0900249313235282
# Linear model: C = 0.0001 score = -1.0897987124405801
# Linear model: C = 0.0005 score = -1.0892650003086775
# Linear model: C = 0.001 score = -1.0888118221502752
# Linear model: C = 0.005 score = -1.0871575786214323
# Linear model: C = 0.01 score = -1.0871575786214323
# Linear model: C = 0.05 score = -1.0851220070052892
# Linear model: C = 0.1 score = -1.0851220070052892
# Linear model: C = 0.5 score = -1.0851220070052892
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.093248499957472
# Linear model: C = 5e-05 score = -1.091627617391199
# Linear model: C = 0.0001 score = -1.0915547128669918
# Linear model: C = 0.0005 score = -1.0910511918507517
# Linear model: C = 0.001 score = -1.090553239556402
# Linear model: C = 0.005 score = -1.0887099104352296
# Linear model: C = 0.01 score = -1.0887085029177368
# Linear model: C = 0.05 score = -1.0861999678067864
# Linear model: C = 0.1 score = -1.0861999678067864
# Linear model: C = 0.5 score = -1.0861999678067864
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0929883482940494
# Linear model: C = 5e-05 score = -1.0909559441007675
# Linear model: C = 0.0001 score = -1.0907725040189922
# Linear model: C = 0.0005 score = -1.0902443438470364
# Linear model: C = 0.001 score = -1.0898490209497511
# Linear model: C = 0.005 score = -1.088394220865518
# Linear model: C = 0.01 score = -1.088394220865518
# Linear model: C = 0.05 score = -1.086767020969838
# Linear model: C = 0.1 score = -1.086767020969838
# Linear model: C = 0.5 score = -1.086767020969838
# Lvl_1_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 13342.315784692764
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09571
# [200]	valid's multi_logloss: 1.09863
# Early stopping, best iteration is:
# [66]	valid's multi_logloss: 1.09472
#
# ===== Start working with fold 1 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.0919
# [200]	valid's multi_logloss: 1.09382
# Early stopping, best iteration is:
# [71]	valid's multi_logloss: 1.09153
#
# ===== Start working with fold 2 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09113
# [200]	valid's multi_logloss: 1.09334
# Early stopping, best iteration is:
# [77]	valid's multi_logloss: 1.09057
#
# ===== Start working with fold 3 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09285
# [200]	valid's multi_logloss: 1.09504
# Early stopping, best iteration is:
# [64]	valid's multi_logloss: 1.09195
#
# ===== Start working with fold 4 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09143
# [200]	valid's multi_logloss: 1.09359
# Early stopping, best iteration is:
# [78]	valid's multi_logloss: 1.09103
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Time left 13238.884853839874
# Blending: Optimization starts with equal weights and score -1.0885568182907999
# Blending, iter 0: score = -1.0875655406031013, weights = [0.9230269  0.07697308]
# Blending, iter 1: score = -1.0875655406031013, weights = [0.9230269  0.07697308]
# No score update. Terminated
#
# Automl preset training completed in 1162.36 seconds.
# Current random state: {'reader_params': {'random_state': 43}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'random_state': 43}
# Start automl preset with listed constraints:
# - time: 13237.5998544693 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (100000, 51)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 13194.70852804184 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1091266504511237
# Linear model: C = 5e-05 score = -1.1021069825328886
# Linear model: C = 0.0001 score = -1.1007621327914296
# Linear model: C = 0.0005 score = -1.099870580240339
# Linear model: C = 0.001 score = -1.0998274851299823
# Linear model: C = 0.005 score = -1.099807247442752
# Linear model: C = 0.01 score = -1.099807169289887
# Linear model: C = 0.05 score = -1.0998061402387918
# Linear model: C = 0.1 score = -1.0998061402387918
# Linear model: C = 0.5 score = -1.0998061402387918
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1092991031706334
# Linear model: C = 5e-05 score = -1.1025956798784435
# Linear model: C = 0.0001 score = -1.1014362063266336
# Linear model: C = 0.0005 score = -1.1008155574306846
# Linear model: C = 0.001 score = -1.1008213473916053
# Linear model: C = 0.005 score = -1.1008469517707824
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1096375161528587
# Linear model: C = 5e-05 score = -1.1032386538386345
# Linear model: C = 0.0001 score = -1.1021104795582592
# Linear model: C = 0.0005 score = -1.1015318127505482
# Linear model: C = 0.001 score = -1.1015465485095979
# Linear model: C = 0.005 score = -1.1015749222405256
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1096684532254935
# Linear model: C = 5e-05 score = -1.1033203957736493
# Linear model: C = 0.0001 score = -1.1022673673219978
# Linear model: C = 0.0005 score = -1.101747645253688
# Linear model: C = 0.001 score = -1.101766477688402
# Linear model: C = 0.005 score = -1.1018059659034014
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.1099598630428313
# Linear model: C = 5e-05 score = -1.1042569795407355
# Linear model: C = 0.0001 score = -1.1034362160652875
# Linear model: C = 0.0005 score = -1.103365045529604
# Linear model: C = 0.001 score = -1.1034382160022855
# Linear model: C = 0.005 score = -1.1035462290279567
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 13180.297738313675
# Start fitting Selector_LightGBM ...
#
# ===== Start working with fold 0 for Selector_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09528
# [200]	valid's multi_logloss: 1.09456
# [300]	valid's multi_logloss: 1.09651
# Early stopping, best iteration is:
# [154]	valid's multi_logloss: 1.09402
# Selector_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09524
# [200]	valid's multi_logloss: 1.09361
# [300]	valid's multi_logloss: 1.09476
# Early stopping, best iteration is:
# [171]	valid's multi_logloss: 1.09348
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09501
# [200]	valid's multi_logloss: 1.09216
# [300]	valid's multi_logloss: 1.09283
# Early stopping, best iteration is:
# [195]	valid's multi_logloss: 1.09211
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09607
# [200]	valid's multi_logloss: 1.09449
# [300]	valid's multi_logloss: 1.09559
# Early stopping, best iteration is:
# [192]	valid's multi_logloss: 1.09437
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09644
# [200]	valid's multi_logloss: 1.09479
# [300]	valid's multi_logloss: 1.09591
# [400]	valid's multi_logloss: 1.09747
# Early stopping, best iteration is:
# [213]	valid's multi_logloss: 1.09471
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09728
# [200]	valid's multi_logloss: 1.09578
# [300]	valid's multi_logloss: 1.09661
# Early stopping, best iteration is:
# [165]	valid's multi_logloss: 1.09565
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 2489.3190380693636 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09566
# [200]	valid's multi_logloss: 1.0993
# [300]	valid's multi_logloss: 1.10539
# Early stopping, best iteration is:
# [103]	valid's multi_logloss: 1.09561
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09648
# [200]	valid's multi_logloss: 1.09918
# [300]	valid's multi_logloss: 1.10433
# Early stopping, best iteration is:
# [100]	valid's multi_logloss: 1.09648
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10018
# Early stopping, best iteration is:
# [59]	valid's multi_logloss: 1.09739
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.09871
# Early stopping, best iteration is:
# [79]	valid's multi_logloss: 1.09719
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10034
# Early stopping, best iteration is:
# [51]	valid's multi_logloss: 1.0983
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10112
# Early stopping, best iteration is:
# [54]	valid's multi_logloss: 1.09879
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's multi_logloss: 1.10074
# Early stopping, best iteration is:
# [54]	valid's multi_logloss: 1.09838
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3686025	test: 1.3686146	best: 1.3686146 (0)	total: 41.5ms	remaining: 2m 4s
# 100:	learn: 1.1083817	test: 1.1105746	best: 1.1105746 (100)	total: 3.84s	remaining: 1m 50s
# 200:	learn: 1.0980962	test: 1.1029748	best: 1.1029748 (200)	total: 7.9s	remaining: 1m 49s
# 300:	learn: 1.0917501	test: 1.0993829	best: 1.0993829 (300)	total: 11.8s	remaining: 1m 45s
# 400:	learn: 1.0864834	test: 1.0968547	best: 1.0968547 (400)	total: 15.9s	remaining: 1m 42s
# 500:	learn: 1.0810444	test: 1.0949772	best: 1.0949772 (500)	total: 19.9s	remaining: 1m 39s
# 600:	learn: 1.0764288	test: 1.0937987	best: 1.0937987 (600)	total: 24s	remaining: 1m 35s
# 700:	learn: 1.0722929	test: 1.0930155	best: 1.0930137 (697)	total: 27.9s	remaining: 1m 31s
# 800:	learn: 1.0684085	test: 1.0925237	best: 1.0925237 (800)	total: 32.1s	remaining: 1m 28s
# 900:	learn: 1.0647658	test: 1.0922285	best: 1.0922172 (897)	total: 36s	remaining: 1m 23s
# 1000:	learn: 1.0612276	test: 1.0919984	best: 1.0919975 (998)	total: 39.8s	remaining: 1m 19s
# 1100:	learn: 1.0578789	test: 1.0919183	best: 1.0918892 (1097)	total: 43.6s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091889226
# bestIteration = 1097
#
# Shrink model to first 1098 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3686042	test: 1.3686102	best: 1.3686102 (0)	total: 37.6ms	remaining: 1m 52s
# 100:	learn: 1.1082587	test: 1.1103735	best: 1.1103735 (100)	total: 3.83s	remaining: 1m 49s
# 200:	learn: 1.0981376	test: 1.1028166	best: 1.1028166 (200)	total: 7.81s	remaining: 1m 48s
# 300:	learn: 1.0917545	test: 1.0990164	best: 1.0990140 (299)	total: 11.8s	remaining: 1m 45s
# 400:	learn: 1.0863478	test: 1.0965663	best: 1.0965663 (400)	total: 16.1s	remaining: 1m 44s
# 500:	learn: 1.0811216	test: 1.0945189	best: 1.0945189 (500)	total: 20.1s	remaining: 1m 40s
# 600:	learn: 1.0765590	test: 1.0933665	best: 1.0933665 (600)	total: 23.9s	remaining: 1m 35s
# 700:	learn: 1.0724374	test: 1.0925866	best: 1.0925866 (700)	total: 27.8s	remaining: 1m 31s
# 800:	learn: 1.0685352	test: 1.0919655	best: 1.0919654 (798)	total: 31.9s	remaining: 1m 27s
# 900:	learn: 1.0648202	test: 1.0916376	best: 1.0915970 (893)	total: 36s	remaining: 1m 23s
# 1000:	learn: 1.0613285	test: 1.0913013	best: 1.0912950 (999)	total: 39.9s	remaining: 1m 19s
# 1100:	learn: 1.0578866	test: 1.0911678	best: 1.0911325 (1083)	total: 43.8s	remaining: 1m 15s
# 1200:	learn: 1.0547615	test: 1.0910254	best: 1.0910078 (1180)	total: 47.7s	remaining: 1m 11s
# 1300:	learn: 1.0515125	test: 1.0909617	best: 1.0909541 (1294)	total: 51.7s	remaining: 1m 7s
# 1400:	learn: 1.0485258	test: 1.0908003	best: 1.0907958 (1399)	total: 55.5s	remaining: 1m 3s
# 1500:	learn: 1.0455007	test: 1.0906865	best: 1.0906853 (1499)	total: 59.3s	remaining: 59.2s
# 1600:	learn: 1.0425406	test: 1.0906022	best: 1.0906005 (1598)	total: 1m 3s	remaining: 55.3s
# 1700:	learn: 1.0396094	test: 1.0906548	best: 1.0905702 (1663)	total: 1m 7s	remaining: 51.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.090570154
# bestIteration = 1663
#
# Shrink model to first 1664 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3686012	test: 1.3686167	best: 1.3686167 (0)	total: 38.5ms	remaining: 1m 55s
# 100:	learn: 1.1081759	test: 1.1109395	best: 1.1109395 (100)	total: 3.83s	remaining: 1m 49s
# 200:	learn: 1.0978810	test: 1.1035922	best: 1.1035922 (200)	total: 7.83s	remaining: 1m 49s
# 300:	learn: 1.0916248	test: 1.1002473	best: 1.1002473 (300)	total: 12s	remaining: 1m 47s
# 400:	learn: 1.0861178	test: 1.0977612	best: 1.0977612 (400)	total: 16s	remaining: 1m 43s
# 500:	learn: 1.0807703	test: 1.0959207	best: 1.0959207 (500)	total: 19.9s	remaining: 1m 39s
# 600:	learn: 1.0762721	test: 1.0947340	best: 1.0947340 (600)	total: 23.8s	remaining: 1m 35s
# 700:	learn: 1.0719031	test: 1.0939434	best: 1.0939434 (700)	total: 27.8s	remaining: 1m 31s
# 800:	learn: 1.0681475	test: 1.0934750	best: 1.0934750 (800)	total: 31.6s	remaining: 1m 26s
# 900:	learn: 1.0644466	test: 1.0931505	best: 1.0931505 (900)	total: 35.3s	remaining: 1m 22s
# 1000:	learn: 1.0610569	test: 1.0929335	best: 1.0929335 (1000)	total: 39.1s	remaining: 1m 18s
# 1100:	learn: 1.0576447	test: 1.0927599	best: 1.0927353 (1069)	total: 42.8s	remaining: 1m 13s
# 1200:	learn: 1.0543737	test: 1.0926799	best: 1.0926541 (1191)	total: 46.9s	remaining: 1m 10s
# 1300:	learn: 1.0512100	test: 1.0925626	best: 1.0925572 (1263)	total: 50.7s	remaining: 1m 6s
# 1400:	learn: 1.0481062	test: 1.0926514	best: 1.0925464 (1360)	total: 54.6s	remaining: 1m 2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092546408
# bestIteration = 1360
#
# Shrink model to first 1361 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3686007	test: 1.3686108	best: 1.3686108 (0)	total: 37.7ms	remaining: 1m 52s
# 100:	learn: 1.1082497	test: 1.1102998	best: 1.1102998 (100)	total: 3.83s	remaining: 1m 49s
# 200:	learn: 1.0980313	test: 1.1031743	best: 1.1031743 (200)	total: 7.79s	remaining: 1m 48s
# 300:	learn: 1.0915738	test: 1.0998733	best: 1.0998733 (300)	total: 11.6s	remaining: 1m 44s
# 400:	learn: 1.0862313	test: 1.0976342	best: 1.0976342 (400)	total: 15.5s	remaining: 1m 40s
# 500:	learn: 1.0807719	test: 1.0959136	best: 1.0959136 (500)	total: 19.8s	remaining: 1m 38s
# 600:	learn: 1.0760850	test: 1.0948653	best: 1.0948653 (600)	total: 24.1s	remaining: 1m 36s
# 700:	learn: 1.0719322	test: 1.0940940	best: 1.0940940 (700)	total: 28.1s	remaining: 1m 32s
# 800:	learn: 1.0681057	test: 1.0934890	best: 1.0934890 (800)	total: 31.9s	remaining: 1m 27s
# 900:	learn: 1.0645858	test: 1.0933481	best: 1.0933474 (899)	total: 35.7s	remaining: 1m 23s
# 1000:	learn: 1.0611018	test: 1.0931017	best: 1.0930855 (976)	total: 39.5s	remaining: 1m 18s
# 1100:	learn: 1.0578112	test: 1.0929768	best: 1.0929438 (1089)	total: 43.2s	remaining: 1m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092943824
# bestIteration = 1089
#
# Shrink model to first 1090 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
#
# 0:	learn: 1.3685987	test: 1.3686220	best: 1.3686220 (0)	total: 37.7ms	remaining: 1m 53s
# 100:	learn: 1.1080590	test: 1.1104368	best: 1.1104368 (100)	total: 3.77s	remaining: 1m 48s
# 200:	learn: 1.0978421	test: 1.1034247	best: 1.1034247 (200)	total: 8.11s	remaining: 1m 52s
# 300:	learn: 1.0912376	test: 1.1001125	best: 1.1001125 (300)	total: 12.2s	remaining: 1m 48s
# 400:	learn: 1.0859575	test: 1.0980551	best: 1.0980551 (400)	total: 16.1s	remaining: 1m 44s
# 500:	learn: 1.0805240	test: 1.0963054	best: 1.0963054 (500)	total: 20.1s	remaining: 1m 40s
# 600:	learn: 1.0758507	test: 1.0952987	best: 1.0952987 (600)	total: 23.9s	remaining: 1m 35s
# 700:	learn: 1.0716780	test: 1.0947033	best: 1.0947005 (697)	total: 27.7s	remaining: 1m 30s
# 800:	learn: 1.0677964	test: 1.0941631	best: 1.0941631 (800)	total: 31.6s	remaining: 1m 26s
# 900:	learn: 1.0641147	test: 1.0937800	best: 1.0937786 (899)	total: 35.5s	remaining: 1m 22s
# 1000:	learn: 1.0605615	test: 1.0935363	best: 1.0935322 (999)	total: 39.6s	remaining: 1m 19s
# 1100:	learn: 1.0571571	test: 1.0935878	best: 1.0934509 (1038)	total: 43.5s	remaining: 1m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093450877
# bestIteration = 1038
#
# Shrink model to first 1039 iterations.
# Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# Optuna may run 8133.379006810808 secs
# Start fitting Lvl_0_Pipe_1_Mod_3_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3686033	test: 1.3686137	best: 1.3686137 (0)	total: 36.8ms	remaining: 1m 50s
# 100:	learn: 1.1101128	test: 1.1111563	best: 1.1111563 (100)	total: 3.53s	remaining: 1m 41s
# 200:	learn: 1.1016298	test: 1.1042790	best: 1.1042790 (200)	total: 7.24s	remaining: 1m 40s
# 300:	learn: 1.0966053	test: 1.1007264	best: 1.1007264 (300)	total: 10.8s	remaining: 1m 36s
# 400:	learn: 1.0924241	test: 1.0981764	best: 1.0981764 (400)	total: 14.4s	remaining: 1m 33s
# 500:	learn: 1.0885542	test: 1.0962766	best: 1.0962766 (500)	total: 18s	remaining: 1m 29s
# 600:	learn: 1.0852782	test: 1.0950095	best: 1.0950073 (597)	total: 21.6s	remaining: 1m 26s
# 700:	learn: 1.0824131	test: 1.0941481	best: 1.0941481 (700)	total: 25.3s	remaining: 1m 23s
# 800:	learn: 1.0798433	test: 1.0935728	best: 1.0935728 (800)	total: 29.1s	remaining: 1m 19s
# 900:	learn: 1.0774688	test: 1.0931085	best: 1.0931085 (900)	total: 32.6s	remaining: 1m 15s
# 1000:	learn: 1.0751336	test: 1.0927362	best: 1.0927362 (1000)	total: 36.1s	remaining: 1m 12s
# 1100:	learn: 1.0729263	test: 1.0924370	best: 1.0924297 (1096)	total: 39.6s	remaining: 1m 8s
# 1200:	learn: 1.0708276	test: 1.0922222	best: 1.0922205 (1192)	total: 43.1s	remaining: 1m 4s
# 1300:	learn: 1.0687925	test: 1.0922153	best: 1.0921473 (1254)	total: 46.6s	remaining: 1m
# 1400:	learn: 1.0669912	test: 1.0921570	best: 1.0921350 (1365)	total: 50.1s	remaining: 57.2s
# 1500:	learn: 1.0650560	test: 1.0921981	best: 1.0921330 (1413)	total: 53.7s	remaining: 53.6s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.09213298
# bestIteration = 1413
#
# Shrink model to first 1414 iterations.
# Lvl_0_Pipe_1_Mod_3_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_3_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3686033	test: 1.3686137	best: 1.3686137 (0)	total: 34.1ms	remaining: 1m 42s
# 100:	learn: 1.1101128	test: 1.1111563	best: 1.1111563 (100)	total: 3.63s	remaining: 1m 44s
# 200:	learn: 1.1016298	test: 1.1042790	best: 1.1042790 (200)	total: 7.95s	remaining: 1m 50s
# 300:	learn: 1.0966053	test: 1.1007264	best: 1.1007264 (300)	total: 11.6s	remaining: 1m 44s
# ...
# 1200:	learn: 1.0710934	test: 1.0918381	best: 1.0918381 (1200)	total: 43s	remaining: 1m 4s
# 1300:	learn: 1.0689487	test: 1.0918139	best: 1.0918120 (1249)	total: 46.5s	remaining: 1m
# 1400:	learn: 1.0669954	test: 1.0917583	best: 1.0917378 (1379)	total: 50s	remaining: 57s
# 1500:	learn: 1.0650079	test: 1.0917371	best: 1.0917243 (1498)	total: 53.5s	remaining: 53.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091724339
# bestIteration = 1498
#
# Shrink model to first 1499 iterations.
# Lvl_0_Pipe_1_Mod_3_CatBoost fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_3_CatBoost ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3686011	test: 1.3686179	best: 1.3686179 (0)	total: 32ms	remaining: 1m 35s
# 100:	learn: 1.1106333	test: 1.1112221	best: 1.1112221 (100)	total: 3.44s	remaining: 1m 38s
# 200:	learn: 1.1019736	test: 1.1038267	best: 1.1038267 (200)	total: 7.03s	remaining: 1m 37s
# 300:	learn: 1.0968456	test: 1.1000934	best: 1.1000934 (300)	total: 10.6s	remaining: 1m 35s
# 400:	learn: 1.0927559	test: 1.0974270	best: 1.0974270 (400)	total: 14.8s	remaining: 1m 35s
# 500:	learn: 1.0888237	test: 1.0954588	best: 1.0954588 (500)	total: 18.4s	remaining: 1m 31s
# 600:	learn: 1.0854953	test: 1.0941903	best: 1.0941903 (600)	total: 22s	remaining: 1m 27s
# 700:	learn: 1.0826304	test: 1.0933195	best: 1.0933195 (700)	total: 25.5s	remaining: 1m 23s
# 800:	learn: 1.0800288	test: 1.0928161	best: 1.0928161 (800)	total: 29.3s	remaining: 1m 20s
# 900:	learn: 1.0775539	test: 1.0924380	best: 1.0924291 (899)	total: 33.1s	remaining: 1m 17s
# 1000:	learn: 1.0752946	test: 1.0921944	best: 1.0921725 (990)	total: 36.6s	remaining: 1m 13s
# 1100:	learn: 1.0731963	test: 1.0919841	best: 1.0919637 (1090)	total: 40s	remaining: 1m 9s
# 1200:	learn: 1.0710934	test: 1.0918381	best: 1.0918381 (1200)	total: 43.5s	remaining: 1m 5s
# 1300:	learn: 1.0689487	test: 1.0918139	best: 1.0918120 (1249)	total: 47.4s	remaining: 1m 1s
# 1400:	learn: 1.0669954	test: 1.0917583	best: 1.0917378 (1379)	total: 50.8s	remaining: 57.9s
# 1500:	learn: 1.0650079	test: 1.0917371	best: 1.0917243 (1498)	total: 54.2s	remaining: 54.1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091724339
# bestIteration = 1498
#
# Shrink model to first 1499 iterations.
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3686030	test: 1.3686159	best: 1.3686159 (0)	total: 35.1ms	remaining: 1m 45s
# 100:	learn: 1.1105709	test: 1.1115122	best: 1.1115122 (100)	total: 3.88s	remaining: 1m 51s
# 200:	learn: 1.1017004	test: 1.1043892	best: 1.1043892 (200)	total: 7.58s	remaining: 1m 45s
# 300:	learn: 1.0965937	test: 1.1009144	best: 1.1009144 (300)	total: 11.1s	remaining: 1m 39s
# 400:	learn: 1.0924783	test: 1.0984064	best: 1.0984064 (400)	total: 14.6s	remaining: 1m 34s
# 500:	learn: 1.0886204	test: 1.0964444	best: 1.0964444 (500)	total: 18.2s	remaining: 1m 30s
# 600:	learn: 1.0853812	test: 1.0949826	best: 1.0949826 (600)	total: 22.2s	remaining: 1m 28s
# 700:	learn: 1.0825289	test: 1.0941470	best: 1.0941470 (700)	total: 25.6s	remaining: 1m 23s
# 800:	learn: 1.0798697	test: 1.0935598	best: 1.0935598 (800)	total: 29.2s	remaining: 1m 20s
# 900:	learn: 1.0774910	test: 1.0930687	best: 1.0930687 (900)	total: 32.5s	remaining: 1m 15s
# 1000:	learn: 1.0752190	test: 1.0928146	best: 1.0928146 (1000)	total: 36.3s	remaining: 1m 12s
# 1100:	learn: 1.0730311	test: 1.0925361	best: 1.0925361 (1100)	total: 39.7s	remaining: 1m 8s
# 1200:	learn: 1.0709389	test: 1.0923087	best: 1.0923087 (1200)	total: 43.1s	remaining: 1m 4s
# 1300:	learn: 1.0689493	test: 1.0921385	best: 1.0921280 (1263)	total: 46.4s	remaining: 1m
# 1400:	learn: 1.0670242	test: 1.0920997	best: 1.0920820 (1346)	total: 49.7s	remaining: 56.7s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092081957
# bestIteration = 1346
#
# Shrink model to first 1347 iterations.
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3686056	test: 1.3686178	best: 1.3686178 (0)	total: 46.8ms	remaining: 2m 20s
# 100:	learn: 1.1101727	test: 1.1118010	best: 1.1118010 (100)	total: 3.9s	remaining: 1m 52s
# 200:	learn: 1.1014890	test: 1.1049128	best: 1.1049128 (200)	total: 7.55s	remaining: 1m 45s
# 300:	learn: 1.0963920	test: 1.1012849	best: 1.1012849 (300)	total: 11.1s	remaining: 1m 39s
# 400:	learn: 1.0922495	test: 1.0987827	best: 1.0987827 (400)	total: 15s	remaining: 1m 37s
# 500:	learn: 1.0883833	test: 1.0967993	best: 1.0967993 (500)	total: 18.5s	remaining: 1m 32s
# 600:	learn: 1.0850487	test: 1.0954051	best: 1.0954051 (600)	total: 22s	remaining: 1m 27s
# 700:	learn: 1.0821334	test: 1.0945355	best: 1.0945355 (700)	total: 25.4s	remaining: 1m 23s
# 800:	learn: 1.0795283	test: 1.0940242	best: 1.0940242 (800)	total: 28.8s	remaining: 1m 19s
# 900:	learn: 1.0770761	test: 1.0936519	best: 1.0936519 (900)	total: 32.3s	remaining: 1m 15s
# 1000:	learn: 1.0747914	test: 1.0933183	best: 1.0933183 (1000)	total: 36.3s	remaining: 1m 12s
# 1100:	learn: 1.0726219	test: 1.0930309	best: 1.0930309 (1100)	total: 39.7s	remaining: 1m 8s
# 1200:	learn: 1.0705614	test: 1.0929100	best: 1.0928921 (1194)	total: 43.2s	remaining: 1m 4s
# 1300:	learn: 1.0686316	test: 1.0927802	best: 1.0927640 (1294)	total: 46.9s	remaining: 1m 1s
# 1400:	learn: 1.0666192	test: 1.0926725	best: 1.0926424 (1391)	total: 50.2s	remaining: 57.3s
# 1500:	learn: 1.0647333	test: 1.0926100	best: 1.0926050 (1471)	total: 53.6s	remaining: 53.6s
# 1600:	learn: 1.0629137	test: 1.0924755	best: 1.0924755 (1600)	total: 57s	remaining: 49.8s
# 1700:	learn: 1.0611574	test: 1.0923676	best: 1.0923627 (1699)	total: 1m	remaining: 46s
# 1800:	learn: 1.0592941	test: 1.0923642	best: 1.0923236 (1770)	total: 1m 3s	remaining: 42.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.092323631
# bestIteration = 1770
#
# Shrink model to first 1771 iterations.
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3686035	test: 1.3686061	best: 1.3686061 (0)	total: 44.4ms	remaining: 2m 13s
# 100:	learn: 1.1104540	test: 1.1115374	best: 1.1115374 (100)	total: 3.92s	remaining: 1m 52s
# 200:	learn: 1.1018227	test: 1.1043788	best: 1.1043788 (200)	total: 7.56s	remaining: 1m 45s
# 300:	learn: 1.0967841	test: 1.1007199	best: 1.1007199 (300)	total: 11.1s	remaining: 1m 39s
# 400:	learn: 1.0926057	test: 1.0980234	best: 1.0980234 (400)	total: 14.9s	remaining: 1m 36s
# 500:	learn: 1.0887081	test: 1.0959298	best: 1.0959298 (500)	total: 18.4s	remaining: 1m 31s
# 600:	learn: 1.0854771	test: 1.0947009	best: 1.0947009 (600)	total: 21.9s	remaining: 1m 27s
# 700:	learn: 1.0825474	test: 1.0938229	best: 1.0938229 (700)	total: 25.3s	remaining: 1m 23s
# 800:	learn: 1.0799418	test: 1.0930638	best: 1.0930638 (800)	total: 28.8s	remaining: 1m 19s
# 900:	learn: 1.0775718	test: 1.0926201	best: 1.0926103 (898)	total: 32.3s	remaining: 1m 15s
# 1000:	learn: 1.0752284	test: 1.0922794	best: 1.0922753 (995)	total: 36.3s	remaining: 1m 12s
# 1100:	learn: 1.0730511	test: 1.0920428	best: 1.0920369 (1099)	total: 39.6s	remaining: 1m 8s
# 1200:	learn: 1.0709502	test: 1.0918029	best: 1.0918029 (1200)	total: 43.2s	remaining: 1m 4s
# 1300:	learn: 1.0689492	test: 1.0916360	best: 1.0916353 (1299)	total: 46.9s	remaining: 1m 1s
# 1400:	learn: 1.0669295	test: 1.0915107	best: 1.0915054 (1382)	total: 50.2s	remaining: 57.3s
# 1500:	learn: 1.0651131	test: 1.0913889	best: 1.0913768 (1491)	total: 53.5s	remaining: 53.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.091376811
# bestIteration = 1491
#
# Shrink model to first 1492 iterations.
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_3_CatBoost =====
#
# 0:	learn: 1.3685997	test: 1.3686195	best: 1.3686195 (0)	total: 33.1ms	remaining: 1m 39s
# 100:	learn: 1.1098010	test: 1.1122985	best: 1.1122985 (100)	total: 3.47s	remaining: 1m 39s
# 200:	learn: 1.1009941	test: 1.1056515	best: 1.1056515 (200)	total: 7.16s	remaining: 1m 39s
# 300:	learn: 1.0960025	test: 1.1023928	best: 1.1023928 (300)	total: 10.7s	remaining: 1m 35s
# 400:	learn: 1.0918306	test: 1.1000262	best: 1.1000262 (400)	total: 14.8s	remaining: 1m 36s
# 500:	learn: 1.0880100	test: 1.0980715	best: 1.0980715 (500)	total: 18.6s	remaining: 1m 32s
# 600:	learn: 1.0847265	test: 1.0968562	best: 1.0968562 (600)	total: 22.2s	remaining: 1m 28s
# 700:	learn: 1.0818817	test: 1.0960091	best: 1.0960091 (700)	total: 25.6s	remaining: 1m 24s
# 800:	learn: 1.0793302	test: 1.0953451	best: 1.0953330 (796)	total: 29.2s	remaining: 1m 20s
# 900:	learn: 1.0768994	test: 1.0950159	best: 1.0950159 (900)	total: 32.7s	remaining: 1m 16s
# 1000:	learn: 1.0745727	test: 1.0946186	best: 1.0946186 (1000)	total: 36.1s	remaining: 1m 12s
# 1100:	learn: 1.0724430	test: 1.0944125	best: 1.0944125 (1100)	total: 39.6s	remaining: 1m 8s
# 1200:	learn: 1.0702969	test: 1.0942226	best: 1.0942226 (1200)	total: 42.9s	remaining: 1m 4s
# 1300:	learn: 1.0683087	test: 1.0941330	best: 1.0941163 (1289)	total: 46.9s	remaining: 1m 1s
# 1400:	learn: 1.0663532	test: 1.0940907	best: 1.0940739 (1395)	total: 50.6s	remaining: 57.7s
# 1500:	learn: 1.0644686	test: 1.0940430	best: 1.0940430 (1500)	total: 54s	remaining: 54s
# 1600:	learn: 1.0625911	test: 1.0940027	best: 1.0939409 (1569)	total: 57.4s	remaining: 50.2s
# 1700:	learn: 1.0607767	test: 1.0939216	best: 1.0938832 (1665)	total: 1m	remaining: 46.6s
# 1800:	learn: 1.0589903	test: 1.0939066	best: 1.0938713 (1762)	total: 1m 4s	remaining: 42.9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 1.093871264
# bestIteration = 1762
#
# Shrink model to first 1763 iterations.
# Lvl_0_Pipe_1_Mod_3_CatBoost fitting and predicting completed
# Time left 1316.6632239818573
# Layer 1 training completed.
#
#
# Layer 2 ...
# Train process start. Time left 1316.553059577942 secs
# Start fitting Lvl_1_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0932142755791545
# Linear model: C = 5e-05 score = -1.0914547005929054
# Linear model: C = 0.0001 score = -1.0914422038577496
# Linear model: C = 0.0005 score = -1.090580816859007
# Linear model: C = 0.001 score = -1.089773736910522
# Linear model: C = 0.005 score = -1.0875192877709865
# Linear model: C = 0.01 score = -1.0875192877709865
# Linear model: C = 0.05 score = -1.0875193995133043
#
# ===== Start working with fold 1 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0932776827454567
# Linear model: C = 5e-05 score = -1.0913499050356448
# Linear model: C = 0.0001 score = -1.0911928242750466
# Linear model: C = 0.0005 score = -1.0904385652922093
# Linear model: C = 0.001 score = -1.0898107088521123
# Linear model: C = 0.005 score = -1.0879958841875195
# Linear model: C = 0.01 score = -1.0879958841875195
# Linear model: C = 0.05 score = -1.087995375458151
# Linear model: C = 0.1 score = -1.0879948671281339
# Linear model: C = 0.5 score = -1.0879945042073726
# Linear model: C = 1 score = -1.0879940155506134
# Linear model: C = 5 score = -1.0859710550777615
# Linear model: C = 10 score = -1.0859710550777615
# Linear model: C = 50 score = -1.0859710550777615
#
# ===== Start working with fold 2 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0939312003031374
# Linear model: C = 5e-05 score = -1.0922290690101684
# Linear model: C = 0.0001 score = -1.0920483942374588
# Linear model: C = 0.0005 score = -1.0911379535861314
# Linear model: C = 0.001 score = -1.0904339875154196
# Linear model: C = 0.005 score = -1.0885636233374476
# Linear model: C = 0.01 score = -1.0885636233374476
# Linear model: C = 0.05 score = -1.0885636733755468
#
# ===== Start working with fold 3 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.092706947247684
# Linear model: C = 5e-05 score = -1.0903918833028525
# Linear model: C = 0.0001 score = -1.090117597747594
# Linear model: C = 0.0005 score = -1.0893368586607277
# Linear model: C = 0.001 score = -1.0888588248584419
# Linear model: C = 0.005 score = -1.0877295430559666
# Linear model: C = 0.01 score = -1.0877295430559666
# Linear model: C = 0.05 score = -1.0871625498853623
# Linear model: C = 0.1 score = -1.0871625498853623
# Linear model: C = 0.5 score = -1.0871625498853623
#
# ===== Start working with fold 4 for Lvl_1_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -1.0956337905496358
# Linear model: C = 5e-05 score = -1.094147873237729
# Linear model: C = 0.0001 score = -1.0939809769175948
# Linear model: C = 0.0005 score = -1.0930304161328823
# Linear model: C = 0.001 score = -1.0923739540558308
# Linear model: C = 0.005 score = -1.0905350166104735
# Linear model: C = 0.01 score = -1.0905350166104735
# Linear model: C = 0.05 score = -1.090535992986709
# Lvl_1_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 1283.4915401935577
# Start fitting Lvl_1_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09476
# [200]	valid's multi_logloss: 1.09346
# [300]	valid's multi_logloss: 1.09495
# Early stopping, best iteration is:
# [151]	valid's multi_logloss: 1.09318
#
# ===== Start working with fold 1 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09514
# [200]	valid's multi_logloss: 1.09293
# [300]	valid's multi_logloss: 1.09365
# [400]	valid's multi_logloss: 1.09536
# Early stopping, best iteration is:
# [208]	valid's multi_logloss: 1.09287
#
# ===== Start working with fold 2 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09585
# [200]	valid's multi_logloss: 1.09387
# [300]	valid's multi_logloss: 1.09474
# Early stopping, best iteration is:
# [184]	valid's multi_logloss: 1.0938
#
# ===== Start working with fold 3 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09489
# [200]	valid's multi_logloss: 1.0932
# [300]	valid's multi_logloss: 1.09413
# Early stopping, best iteration is:
# [189]	valid's multi_logloss: 1.09314
#
# ===== Start working with fold 4 for Lvl_1_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's multi_logloss: 1.09852
# [200]	valid's multi_logloss: 1.09693
# [300]	valid's multi_logloss: 1.09855
# Early stopping, best iteration is:
# [197]	valid's multi_logloss: 1.0969
# Lvl_1_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Time left 1177.2406568527222
# Blending: Optimization starts with equal weights and score -1.0895495568190514
# Blending, iter 0: score = -1.0879503065364062, weights = [1. 0.]
# Blending, iter 1: score = -1.0879503065364062, weights = [1. 0.]
# No score update. Terminated
#
# Automl preset training completed in 1102.70 seconds.
# Blending: Optimization starts with equal weights and score -1.0852098113340138
# Blending, iter 0: score = -1.0850452986709773, weights = [0.2486428  0.14340587 0.         0.         0.34604222 0.
#  0.26190913]
# Blending, iter 1: score = -1.0850326253850757, weights = [0.20048639 0.15195233 0.05423117 0.05075162 0.3065105  0.
#  0.23606798]
# Blending, iter 2: score = -1.0850322649498283, weights = [0.19842415 0.13773102 0.05367334 0.05022959 0.3198165  0.
#  0.24012539]
# Blending, iter 3: score = -1.0850322606192528, weights = [0.1985869  0.13784398 0.0535238  0.05027079 0.32007885 0.
#  0.23969573]
# Blending, iter 4: score = -1.0850322607694567, weights = [0.19859703 0.13785103 0.05347548 0.05027336 0.32009518 0.
#  0.23970796]
# lightml_pred:
# array([[0.07883976, 0.37849826, 0.3780377 , 0.16462438],
#        [0.08086324, 0.46573642, 0.3031911 , 0.15020925],
#        [0.10657585, 0.43226787, 0.37542203, 0.08573432],
#        [0.07973219, 0.5717128 , 0.2484022 , 0.10015282],
#        [0.09314113, 0.5744859 , 0.20669568, 0.12567733],
#        [0.08192502, 0.48652625, 0.23249367, 0.19905514],
#        [0.08439654, 0.5797092 , 0.2329136 , 0.10298071],
#        [0.07264543, 0.6558993 , 0.1420857 , 0.12936962],
#        [0.08487875, 0.6446196 , 0.15044369, 0.12005805],
#        [0.09049071, 0.57007813, 0.23295464, 0.10647658]], dtype=float32)
# Shape = (100000, 4)

# %%
# %%time

test_pred = automl.predict(test_df)
print('Prediction for test set:\n{}\nShape = {}'.format(test_pred[:5], test_pred.shape))
# Out:
# Prediction for test set:
# array([[0.0972752 , 0.6254245 , 0.1639225 , 0.11337782],
#        [0.08227223, 0.70333004, 0.12477012, 0.08962765],
#        [0.08403666, 0.6446773 , 0.1732978 , 0.09798831],
#        [0.08272669, 0.55320585, 0.27393508, 0.09013242],
#        [0.0732189 , 0.6282202 , 0.18970132, 0.10885958]], dtype=float32)
# Shape = (50000, 4)
# CPU times: user 7min 24s, sys: 555 ms, total: 7min 25s
# Wall time: 2min 8s

# %% [markdown]
# <h1 style="background-color:LimeGreen; font-family:newtimeroman; font-size:200%; text-align:center; border-radius: 15px 50px;"> Submission </h1>

# %% [markdown]
# submission = pd.DataFrame(y_pred_xgb_test, columns=xgb.classes_)
# submission

# %% [markdown]
# submission.insert(0, 'id', testoriginal['id'])
# submission

# %% [markdown]
# submission.to_csv("submission.csv", index = False)

# %%
sub.iloc[:, 1:] = test_pred.data
sub.to_csv('light_automl_1.csv', index = False)

# %%
sub[sub.columns[1:]] = test_pred
sub.to_csv('alternative.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-41f13e38e685> in <module>
# ----> 1 sub[sub.columns[1:]] = test_pred
#       2 sub.to_csv('alternative.csv', index=False)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3196                 )[1]
#    3197                 self._check_setitem_copy()
# -> 3198                 self.iloc[:, indexer] = value
#    3199
#    3200     def _setitem_frame(self, key, value):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1718             # scalar value
#    1719             for loc in ilocs:
# -> 1720                 self._setitem_single_column(loc, value, pi)
#    1721
#    1722     def _setitem_with_indexer_2d_value(self, indexer, value):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    1815
#    1816         # reset the sliced object if unique
# -> 1817         self.obj._iset_item(loc, ser)
#    1818
#    1819     def _setitem_single_block(self, indexer, value, name: str):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _iset_item(self, loc, value)
#    3220         # technically _sanitize_column expects a label, not a position,
#    3221         #  but the behavior is the same as long as we pass broadcast=False
# -> 3222         value = self._sanitize_column(loc, value, broadcast=False)
#    3223         NDFrame._iset_item(self, loc, value)
#    3224
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3902                     value = maybe_convert_platform(value)
#    3903                 else:
# -> 3904                     value = com.asarray_tuplesafe(value)
#    3905             elif value.ndim == 2:
#    3906                 value = value.copy().T
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/common.py in asarray_tuplesafe(values, dtype)
#     206         return construct_1d_object_array_from_listlike(values)
#     207
# --> 208     result = np.asarray(values, dtype=dtype)
#     209
#     210     if issubclass(result.dtype.type, str):
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /opt/conda/lib/python3.7/site-packages/log_calls/log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# /opt/conda/lib/python3.7/site-packages/lightautoml/dataset/base.py in __getitem__(self, k)
#     141             data = self._get_rows(data, rows)
#     142
# --> 143         dataset.set_data(data, features, roles)
#     144
#     145         return dataset
#
# /opt/conda/lib/python3.7/site-packages/log_calls/log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# /opt/conda/lib/python3.7/site-packages/lightautoml/dataset/np_pd_dataset.py in set_data(self, data, features, roles)
#     171
#     172         """
# --> 173         assert data is None or type(data) is np.ndarray, 'Numpy dataset support only np.ndarray features'
#     174         super().set_data(data, features, roles)
#     175         self._check_dtype()
#
# AssertionError: Numpy dataset support only np.ndarray features
