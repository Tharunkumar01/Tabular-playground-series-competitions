# %% [markdown]
# #### Please upvote if you find the notebook interesting/useful :)
#
# ## Ok, as we can see from version 4 - we can recieve 0.81420 without pseudolabelling.
#
# # Install [AutoWoe](https://github.com/sberbank-ai-lab/AutoMLWhitebox) library
#
# This library is a part of [LightAutoML](https://github.com/sberbank-ai-lab/LightAutoML) framework and is used in Whitebox preset, but here we will show how to use it separately

# %%
# !pip install -U autowoe
# Out:
# Collecting autowoe
#   Downloading AutoWoE-1.2.5-py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 895 kB/s
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from autowoe) (1.1.5)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.7/site-packages (from autowoe) (0.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from autowoe) (1.19.5)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from autowoe) (1.0.1)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.7/site-packages (from autowoe) (3.1.1)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from autowoe) (2021.1)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from autowoe) (0.11.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from autowoe) (0.24.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autowoe) (3.4.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from autowoe) (2.11.3)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.7/site-packages (from autowoe) (6.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from autowoe) (1.5.4)
# Collecting sphinx
#   Downloading Sphinx-3.5.4-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 4.6 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->autowoe) (1.1.1)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.7/site-packages (from lightgbm->autowoe) (0.36.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->autowoe) (2.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe) (7.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autowoe) (2.4.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->autowoe) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe) (20.3.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe) (3.4.0)
# Requirement already satisfied: py>=1.8.2 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe) (1.10.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe) (1.1.1)
# Requirement already satisfied: toml in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe) (0.10.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /opt/conda/lib/python3.7/site-packages (from pytest->autowoe) (0.13.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->autowoe) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->autowoe) (3.7.4.3)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 1.9 MB/s
# Requirement already satisfied: requests>=2.5.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe) (2.25.1)
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe) (49.6.0.post20210108)
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.4-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 3.6 MB/s
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-1.0.3-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 43 kB/s
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 403 kB/s
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 997 kB/s
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 2.1 MB/s
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe) (2.9.0)
# Requirement already satisfied: Pygments>=2.0 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe) (2.8.0)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: docutils<0.17,>=0.12 in /opt/conda/lib/python3.7/site-packages (from sphinx->autowoe) (0.16)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx->autowoe) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx->autowoe) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx->autowoe) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.5.0->sphinx->autowoe) (2020.12.5)
# Installing collected packages: sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, imagesize, alabaster, sphinx, autowoe
# Successfully installed alabaster-0.7.12 autowoe-1.2.5 imagesize-1.2.0 snowballstemmer-2.1.0 sphinx-3.5.4 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-1.0.3 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.4

# %% [markdown]
# # Imports

# %%
# %matplotlib inline

import pandas as pd
import numpy as np

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from matplotlib import pyplot as plt

from autowoe import AutoWoE, ReportDeco
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Data loading

# %%
INPUT_PATH = '../input/tabular-playground-series-apr-2021/'
train_data = pd.read_csv(INPUT_PATH + 'train.csv')
train_data
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male    NaN
# 1                1         0       3         Bryan, Drew    male    NaN
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked
# 0          2      0     209245  27.14  C12239        S
# 1          0      0      27323  13.35     NaN        S
# 2          1      2  CA 457703  71.29     NaN        S
# 3          0      0   A. 10866  13.04     NaN        S
# 4          0      0     427635   7.76     NaN        S
# ...      ...    ...        ...    ...     ...      ...
# 99995      0      0   PC 15008  14.86  D17243        C
# 99996      0      0      13273  11.15     NaN        S
# 99997      0      0        NaN   9.95     NaN        S
# 99998      0      1     458654  30.92     NaN        S
# 99999      0      0     458074  13.96     NaN        S
#
# [100000 rows x 12 columns]

# %%
test_data = pd.read_csv(INPUT_PATH + 'test.csv')
test_data
# Out:
#        PassengerId  Pclass                Name     Sex   Age  SibSp  Parch  \
# 0           100000       3    Holliday, Daniel    male  19.0      0      0
# 1           100001       3    Nguyen, Lorraine  female  53.0      0      0
# 2           100002       1     Harris, Heather  female  19.0      0      0
# 3           100003       2        Larsen, Eric    male  25.0      0      0
# 4           100004       1       Cleary, Sarah  female  17.0      0      2
# ...            ...     ...                 ...     ...   ...    ...    ...
# 99995       199995       3       Cash, Cheryle  female  27.0      0      0
# 99996       199996       1       Brown, Howard    male  59.0      1      0
# 99997       199997       3  Lightfoot, Cameron    male  47.0      0      0
# 99998       199998       1  Jacobsen, Margaret  female  49.0      1      2
# 99999       199999       1    Fishback, Joanna  female  41.0      0      2
#
#          Ticket    Fare   Cabin Embarked
# 0         24745   63.01     NaN        S
# 1         13264    5.81     NaN        S
# 2         25990   38.91  B15315        C
# 3        314011   12.93     NaN        S
# 4         26203   26.89  B22515        C
# ...         ...     ...     ...      ...
# 99995      7686   10.12     NaN        Q
# 99996     13004   68.31     NaN        S
# 99997   4383317   10.87     NaN        S
# 99998  PC 26988   29.68  B20828        C
# 99999  PC 41824  195.41  E13345        C
#
# [100000 rows x 11 columns]

# %%
submission = pd.read_csv(INPUT_PATH + 'sample_submission.csv')
# submission

# %%
print('TRAIN TARGET MEAN = {:.3f}'.format(train_data['Survived'].mean()))
# Out:
# TRAIN TARGET MEAN = 0.428

# %% [markdown]
# # Load OOFs and Test predictions

# %%
import joblib
oof_preds_1, test_preds_1, oof_preds_2, test_preds_2 = joblib.load('../input/lightautoml-interpretable-model-autowoe/both_preproc_preds.pkl')
oofs = 0.48 * oof_preds_1 + (1 - 0.48) * oof_preds_2
test_preds = 0.48 * test_preds_1 + (1-0.48) * test_preds_2

# %%
train_data['preds'] = oofs
test_data['preds'] = test_preds

# %% [markdown]
# # Extra features functions creation

# %%
def create_extra_features_1(data_0):
    data = data_0.copy()
    data.Cabin = data.Cabin.map(lambda x: str(x)[0].strip())
    
    data['Ticket1'] = data.Ticket.map(lambda x:str(x).split()[0] if len(str(x).split()) > 1 else np.nan)
    data['Ticket2'] = data.Ticket.str.replace('\.','', regex=True).\
                    str.replace('(\d+)', '', regex=True).\
                    str.replace(' ', '', regex=True).\
                    replace(r'^\s*$', 'X', regex=True)
    
    data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
    
    data['FirstName'] = data.Name.map(lambda x: str(x).split(',')[0])
    data['Surname'] = data.Name.map(lambda x: str(x).split(',')[1])
    
    for col in ['Name', 'FirstName', 'Surname']:
        data['Counter_' + col] = data[col].map(data.groupby(col)['PassengerId'].count().to_dict())
        
    data.drop(columns = ['Name', 'Surname', 'Ticket'], inplace = True)
    
    for pair in [('Ticket1', 'Cabin'), ('Ticket2', 'Cabin'), 
                 ('Cabin', 'Parch'), ('Ticket1', 'Parch'), ('Ticket2', 'Parch'),
                 ('Cabin', 'Embarked'), ('Ticket1', 'Embarked'), ('Ticket2', 'Embarked'), ('Embarked', 'Parch')
                ]:
        data[pair[0] + '_' + pair[1]] = data[pair[0]].astype(str) + '_' + data[pair[1]].astype(str)
        
    return data

def create_extra_features_2(data_0):
    data = data_0.copy()
    data.Cabin = data.Cabin.map(lambda x: str(x)[0].strip())
    data.Ticket = data.Ticket.map(lambda x:str(x).split()[0] if len(str(x).split()) > 1 else np.nan)
    
    data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
    
    data['FirstName'] = data.Name.map(lambda x: str(x).split(',')[0])
    data['Surname'] = data.Name.map(lambda x: str(x).split(',')[1])
    
    for col in ['Name', 'FirstName', 'Surname']:
        data['Counter_' + col] = data[col].map(data.groupby(col)['PassengerId'].count().to_dict())
        
    data.drop(columns = ['Name', 'Surname'], inplace = True)
    
    return data


all_df = pd.concat([train_data, test_data]).reset_index(drop = True)
print(all_df.shape)
# Out:
# (200000, 13)

# %% [markdown]
# # Train 2 separate models for Sex on full train and pseudolabelled test

# %%
TARGET = 'Survived'

def get_model():
    return AutoWoE(monotonic=False,
                     vif_th=20.,
                     imp_th=0,
                     th_const=32,
                     force_single_split=True,
                     min_bin_size = 0.01,
                     oof_woe=True,
                     n_folds=10,
                     n_jobs=4,
                     regularized_refit=True,
                     verbose=2
            )

def fit_autowoe(data, model_name):
    auto_woe = get_model()
    auto_woe.fit(data.drop('PassengerId', axis = 1), target_name=TARGET)
    train_pred = auto_woe.predict_proba(data)
    print('\t{}: ACCURACY ON TRAIN = {:.5f}'.format(model_name, accuracy_score(data[TARGET], (train_pred > 0.5).astype(int))))
    return auto_woe

def cv_autowoe(data, 
               test_data, 
               n_folds = 5, 
               sex = 'Unknown'):
    
    print('=' * 50)
    print('Start model for sex = {}'.format(sex))
    
    oof_pred = np.array([0.0] * len(data))
    test_pred = np.array([0.0] * len(test_data))
    
    skf = StratifiedKFold(n_splits = n_folds, shuffle = True, random_state = 13)
    models = []
    for fold, (train_index, test_index) in enumerate(skf.split(data[TARGET], data[TARGET])):
        print('\tStart model sex = {}, fold = {}'.format(sex, fold))
        train_data = data.iloc[train_index, :]
        valid_data = data.iloc[test_index, :]
        
        model_name = 'Model_{}_{}'.format(sex, fold)
        model = fit_autowoe(train_data, model_name)
        models.append(model)
        
        val_pred = model.predict_proba(valid_data)
        oof_pred[test_index] = val_pred
        print('\t{}: ACCURACY ON VALID = {:.5f}'.format(model_name, accuracy_score(valid_data[TARGET], (val_pred > 0.5).astype(int))))
        
        test_pred += model.predict_proba(test_data) / n_folds
        print('\t' + '*' * 50)
        
    print('ACCURACY ON OOF = {:.5f}'.format(accuracy_score(data[TARGET], (oof_pred > 0.5).astype(int))))
        
    return models, oof_pred, test_pred

def build_model_split_by_sex(train_data, test_data, n_folds):
    male_models, male_oof_pred, male_test_pred = cv_autowoe(train_data[train_data['Sex'] == 'male'], test_data, n_folds, 'male')
    print('=' * 50 + '\n' + '=' * 50)
    female_models, female_oof_pred, female_test_pred = cv_autowoe(train_data[train_data['Sex'] == 'female'], test_data, n_folds, 'female')
    
    oof_preds = np.array([0.0] * len(train_data))
    oof_preds[train_data['Sex'] == 'male'] = male_oof_pred
    oof_preds[train_data['Sex'] == 'female'] = female_oof_pred
    
    test_preds = np.where(test_data['Sex'] == 'male', male_test_pred, female_test_pred)
    return oof_preds, test_preds

# %%
all_df.head()
# Out:
#    PassengerId  Survived  Pclass              Name   Sex    Age  SibSp  Parch  \
# 0            0       1.0       1  Oconnor, Frankie  male    NaN      2      0
# 1            1       0.0       3       Bryan, Drew  male    NaN      0      0
# 2            2       0.0       3    Owens, Kenneth  male   0.33      1      2
# 3            3       0.0       3     Kramer, James  male  19.00      0      0
# 4            4       1.0       3     Bond, Michael  male  25.00      0      0
#
#       Ticket   Fare   Cabin Embarked     preds
# 0     209245  27.14  C12239        S  0.239244
# 1      27323  13.35     NaN        S  0.093614
# 2  CA 457703  71.29     NaN        S  0.105634
# 3   A. 10866  13.04     NaN        S  0.079921
# 4     427635   7.76     NaN        S  0.093814

# %%
# %%time

gen_feats = create_extra_features_1(all_df)
train_data, test_data = gen_feats[:len(train_data)], gen_feats[len(train_data):]
print(train_data.shape, test_data.shape)
oof_preds_1, test_preds_1 = build_model_split_by_sex(train_data, test_data, 10)
# Out:
# (100000, 27) (100000, 27)
# ==================================================
# Start model for sex = male
# 	Start model sex = male, fold = 0
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8291, number of negative: 32110
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014391 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4942
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205218 -> initscore=-1.353997
# [LightGBM] [Info] Start training from score -1.353997
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	val_set's auc: 0.776074
#  features ['Cabin'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Parch processing...
# Embarked processing...
# Age processing...
# Ticket1 processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Cabin_Embarked processing...
# Ticket1_Parch processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.500636476416736
# Feature Counter_Name removed due to low AUC value 0.5006640904785302
# Feature Counter_FirstName removed due to low AUC value 0.5011708760422806
# Feature Counter_Surname removed due to low AUC value 0.5020002754593224
# Feature Embarked removed due to high VIF value = 22.712123662071072
# Features ['Ticket1_Cabin']: aucs = [0.6529189232793923] was removed due to corr = [0.9158332527793482] with feat Ticket2_Cabin: auc = 0.6659178212573854
# Features ['Ticket1_Embarked']: aucs = [0.6452622427516308] was removed due to corr = [0.9043771840832481] with feat Ticket2_Embarked: auc = 0.6533403393869669
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.7564539725950633, reg_alpha=0.008576356075535963, is_neg=True, min_weights=preds              -0.723178
# Cabin_Embarked     -0.136659
# Pclass             -0.013331
# Cabin_Parch        -0.070897
# Ticket2_Cabin      -0.122700
# Fare               -0.019517
# Embarked_Parch     -0.153928
# Ticket2_Embarked    0.000000
# Ticket2_Parch      -0.164290
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Ticket1             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# dtype: float64)
# preds            -0.701410
# Cabin_Embarked   -0.123926
# Pclass           -0.007387
# Cabin_Parch      -0.053804
# Ticket2_Cabin    -0.106186
# Fare             -0.013199
# Embarked_Parch   -0.139244
# Ticket2_Parch    -0.165998
# dtype: float64
# 	Model_male_0: ACCURACY ON TRAIN = 0.81630
# 	Model_male_0: ACCURACY ON VALID = 0.80845
# 	**************************************************
# 	Start model sex = male, fold = 1
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8344, number of negative: 32057
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007491 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4954
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206530 -> initscore=-1.345973
# [LightGBM] [Info] Start training from score -1.345973
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	val_set's auc: 0.772899
#  features ['Cabin'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Ticket1 processing...
# Embarked processing...
# Age processing...
# Parch processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# Counter_Name processing...
# FamilySize processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Cabin_Embarked processing...
# Ticket1_Parch processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5005406476338795
# Feature Counter_FirstName removed due to low AUC value 0.5002147004699407
# Feature Counter_Surname removed due to low AUC value 0.5032551667628449
# Feature Embarked removed due to high VIF value = 21.57168809343427
# Features ['Ticket1']: aucs = [0.5795347171884548] was removed due to corr = [0.9091857527543725] with feat Ticket2: auc = 0.5814836495883079
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.7564499536712022, reg_alpha=0.008576356075535963, is_neg=True, min_weights=preds              -0.777300
# Cabin_Embarked     -0.164039
# Pclass             -0.034496
# Cabin_Parch        -0.051591
# Ticket2_Embarked    0.000000
# Fare                0.000000
# Ticket2_Cabin      -0.043052
# Embarked_Parch     -0.093349
# Ticket1_Cabin       0.000000
# Ticket1_Embarked   -0.031185
# Ticket2_Parch      -0.185305
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# dtype: float64)
# preds              -0.742501
# Cabin_Embarked     -0.151648
# Pclass             -0.033277
# Cabin_Parch        -0.036307
# Ticket2_Cabin      -0.026296
# Embarked_Parch     -0.076399
# Ticket1_Embarked   -0.019586
# Ticket2_Parch      -0.181200
# dtype: float64
# 	Model_male_1: ACCURACY ON TRAIN = 0.81533
# 	Model_male_1: ACCURACY ON VALID = 0.81575
# 	**************************************************
# 	Start model sex = male, fold = 2
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8325, number of negative: 32076
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006931 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4917
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206059 -> initscore=-1.348845
# [LightGBM] [Info] Start training from score -1.348845
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [21]	val_set's auc: 0.771201
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# Embarked processing...
# Parch processing...
# Cabin processing...
# Age processing...
# preds processing...
# Ticket1 processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# Ticket2_Cabin processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5004271471468958
# Feature Counter_Name removed due to low AUC value 0.5017172031385264
# Feature Counter_FirstName removed due to low AUC value 0.5009743714422652
# Feature Embarked removed due to high VIF value = 24.258505216009794
# Feature Cabin removed due to high VIF value = 21.228246260034787
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.7585005586109654, reg_alpha=0.008576356075535963, is_neg=True, min_weights=preds              -0.755547
# Cabin_Embarked     -0.089618
# Pclass             -0.026805
# Cabin_Parch         0.000000
# Ticket2_Cabin      -0.205921
# Ticket2_Embarked    0.000000
# Fare                0.000000
# Embarked_Parch     -0.153515
# Ticket1_Cabin       0.000000
# Ticket1_Embarked    0.000000
# Ticket2_Parch      -0.122495
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Ticket1             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# Counter_Surname     0.000000
# dtype: float64)
# preds            -0.738889
# Cabin_Embarked   -0.073802
# Pclass           -0.024364
# Ticket2_Cabin    -0.191089
# Embarked_Parch   -0.142458
# Ticket2_Parch    -0.115227
# dtype: float64
# 	Model_male_2: ACCURACY ON TRAIN = 0.81478
# 	Model_male_2: ACCURACY ON VALID = 0.81326
# 	**************************************************
# 	Start model sex = male, fold = 3
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8299, number of negative: 32102
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007082 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4931
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205416 -> initscore=-1.352783
# [LightGBM] [Info] Start training from score -1.352783
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	val_set's auc: 0.782414
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# Embarked processing...
# preds processing...
# Cabin processing...
# Parch processing...
# Age processing...
# Ticket1 processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2 processing...
# Counter_FirstName processing...
# FirstName processing...
# Ticket1_Cabin processing...
# Ticket2_Cabin processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# Ticket2_Parch processing...
# Embarked_Parch processing...
# Cabin_Parch processing...
# Ticket1_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.4998437494141368
# Feature Counter_Name removed due to low AUC value 0.5016834838046214
# Feature Counter_FirstName removed due to low AUC value 0.5011833036894985
# Feature Counter_Surname removed due to low AUC value 0.5006902256011274
# Feature Embarked removed due to high VIF value = 25.655363480375392
# Feature Cabin removed due to high VIF value = 25.067243054045992
# Features ['Ticket1_Embarked']: aucs = [0.640644728297723] was removed due to corr = [0.9070146690543124] with feat Ticket2_Embarked: auc = 0.6549629611852683
# Features ['Ticket1']: aucs = [0.5825718261814301] was removed due to corr = [0.9098952577224665] with feat Ticket2: auc = 0.5831386269298678
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.75883150713068, reg_alpha=0.008576356075535963, is_neg=True, min_weights=preds              -0.750172
# Cabin_Embarked     -0.058596
# Pclass             -0.059105
# Cabin_Parch        -0.056745
# Fare                0.000000
# Ticket2_Cabin      -0.142406
# Ticket2_Embarked   -0.077549
# Ticket1_Cabin       0.000000
# Embarked_Parch     -0.152744
# Ticket2_Parch      -0.146753
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# dtype: float64)
# preds              -0.734164
# Cabin_Embarked     -0.031507
# Pclass             -0.051448
# Cabin_Parch        -0.043746
# Ticket2_Cabin      -0.120816
# Ticket2_Embarked   -0.059030
# Embarked_Parch     -0.135859
# Ticket2_Parch      -0.132749
# dtype: float64
# 	Model_male_3: ACCURACY ON TRAIN = 0.81595
# 	Model_male_3: ACCURACY ON VALID = 0.80969
# 	**************************************************
# 	Start model sex = male, fold = 4
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8314, number of negative: 32088
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012603 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4965
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205782 -> initscore=-1.350541
# [LightGBM] [Info] Start training from score -1.350541
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	val_set's auc: 0.773473
#  features ['Ticket2'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# Embarked processing...
# preds processing...
# Parch processing...
# Cabin processing...
# Age processing...
# Ticket1 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'preds', 'Ticket1', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.500824814891925
# Feature Counter_FirstName removed due to low AUC value 0.5001996218280034
# Feature Counter_Surname removed due to low AUC value 0.5009170441825728
# Feature Cabin removed due to high VIF value = 25.416254131442255
# Feature Embarked removed due to high VIF value = 24.422703189706446
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.7547379533825106, reg_alpha=0.00857606747453063, is_neg=True, min_weights=preds              -0.707236
# Cabin_Embarked     -0.149970
# Pclass             -0.031004
# Cabin_Parch        -0.037758
# Fare               -0.035008
# Ticket2_Cabin      -0.127665
# Embarked_Parch     -0.143043
# Ticket2_Embarked    0.000000
# Ticket1_Cabin       0.000000
# Ticket1_Embarked    0.000000
# Ticket2_Parch      -0.191421
# Ticket1_Parch       0.000000
# Ticket1             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# dtype: float64)
# preds            -0.689152
# Cabin_Embarked   -0.135738
# Pclass           -0.017366
# Cabin_Parch      -0.027334
# Fare             -0.026712
# Ticket2_Cabin    -0.116732
# Embarked_Parch   -0.141239
# Ticket2_Parch    -0.190525
# dtype: float64
# 	Model_male_4: ACCURACY ON TRAIN = 0.81498
# 	Model_male_4: ACCURACY ON VALID = 0.81911
# 	**************************************************
# 	Start model sex = male, fold = 5
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8323, number of negative: 32079
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007291 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4924
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206005 -> initscore=-1.349179
# [LightGBM] [Info] Start training from score -1.349179
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	val_set's auc: 0.771179
#  features ['Cabin'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Age processing...
# Ticket1 processing...
# Embarked processing...
# Parch processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# FamilySize processing...
# Counter_Surname processing...
# Counter_Name processing...
# Ticket2_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5000689578689873
# Feature Counter_Name removed due to low AUC value 0.501254545765526
# Feature Counter_FirstName removed due to low AUC value 0.5002679847776452
# Feature Embarked removed due to high VIF value = 20.811764733127212
# Features ['Ticket1_Embarked']: aucs = [0.6397438279696677] was removed due to corr = [0.9065725477537406] with feat Ticket2_Embarked: auc = 0.6535696516097138
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.7585959775222603, reg_alpha=0.00857606747453063, is_neg=True, min_weights=preds              -0.763189
# Cabin_Embarked     -0.178242
# Pclass             -0.052833
# Cabin_Parch        -0.051285
# Fare                0.000000
# Ticket2_Cabin      -0.040740
# Ticket1_Cabin      -0.001105
# Embarked_Parch     -0.068693
# Ticket2_Embarked   -0.047229
# Ticket2_Parch      -0.187291
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Ticket1             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# Counter_Surname     0.000000
# dtype: float64)
# preds              -0.736349
# Cabin_Embarked     -0.159489
# Pclass             -0.046485
# Cabin_Parch        -0.032672
# Ticket2_Cabin      -0.031763
# Embarked_Parch     -0.061209
# Ticket2_Embarked   -0.028529
# Ticket2_Parch      -0.170893
# dtype: float64
# 	Model_male_5: ACCURACY ON TRAIN = 0.81532
# 	Model_male_5: ACCURACY ON VALID = 0.81643
# 	**************************************************
# 	Start model sex = male, fold = 6
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8287, number of negative: 32115
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4972
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205114 -> initscore=-1.354635
# [LightGBM] [Info] Start training from score -1.354635
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	val_set's auc: 0.772204
#  features ['Cabin'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Embarked processing...
# Ticket1 processing...
# Parch processing...
# Age processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# FamilySize processing...
# Counter_Surname processing...
# Counter_Name processing...
# Ticket2_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5000040408937003
# Feature Counter_Name removed due to low AUC value 0.5037790860086173
# Feature Counter_FirstName removed due to low AUC value 0.5009719554780594
# Feature Counter_Surname removed due to low AUC value 0.5043939123630549
# Feature Embarked removed due to high VIF value = 22.57778080428977
# Feature Ticket1_Embarked removed due to high VIF value = 20.419558187253745
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.7560788441031444, reg_alpha=0.00857606747453063, is_neg=True, min_weights=preds              -0.770574
# Cabin_Embarked     -0.130556
# Pclass             -0.051204
# Cabin_Parch        -0.003598
# Fare                0.000000
# Ticket2_Cabin      -0.120507
# Ticket2_Embarked    0.000000
# Ticket1_Cabin       0.000000
# Embarked_Parch     -0.128359
# Ticket2_Parch      -0.166141
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Ticket1             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# dtype: float64)
# preds            -0.738239
# Cabin_Embarked   -0.110551
# Pclass           -0.041859
# Ticket2_Cabin    -0.119385
# Embarked_Parch   -0.118220
# Ticket2_Parch    -0.159276
# dtype: float64
# 	Model_male_6: ACCURACY ON TRAIN = 0.81449
# 	Model_male_6: ACCURACY ON VALID = 0.82303
# 	**************************************************
# 	Start model sex = male, fold = 7
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8313, number of negative: 32089
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007667 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4930
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205757 -> initscore=-1.350693
# [LightGBM] [Info] Start training from score -1.350693
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	val_set's auc: 0.774794
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Embarked processing...
# Fare processing...
# Cabin processing...
# Age processing...
# preds processing...
# Parch processing...
# Ticket1 processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2 processing...
# FirstName processing...
# Ticket1_Cabin processing...
# Counter_FirstName processing...
# Ticket2_Cabin processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Embarked_Parch processing...
# Ticket1_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5036654300260544
# Feature Counter_FirstName removed due to low AUC value 0.5008428939630871
# Feature Cabin_Embarked removed due to high VIF value = 23.622373680774302
# Feature Ticket1_Embarked removed due to high VIF value = 21.966391935786188
# Features ['Ticket1_Cabin']: aucs = [0.652302328272033] was removed due to corr = [0.9143642104553436] with feat Ticket2_Cabin: auc = 0.6643093599308338
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.7581487051013761, reg_alpha=0.00857606747453063, is_neg=True, min_weights=preds              -0.784048
# Pclass             -0.052306
# Cabin_Parch        -0.029417
# Ticket2_Cabin      -0.172097
# Fare                0.000000
# Ticket2_Embarked   -0.035007
# Embarked_Parch     -0.175855
# Cabin               0.000000
# Embarked            0.000000
# Ticket2_Parch      -0.106854
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Ticket1             0.000000
# Age                 0.000000
# FamilySize          0.000000
# Parch               0.000000
# SibSp               0.000000
# Counter_Surname     0.000000
# dtype: float64)
# preds              -0.755002
# Pclass             -0.047897
# Cabin_Parch        -0.022685
# Ticket2_Cabin      -0.158513
# Ticket2_Embarked   -0.017092
# Embarked_Parch     -0.168813
# Ticket2_Parch      -0.097643
# dtype: float64
# 	Model_male_7: ACCURACY ON TRAIN = 0.81552
# 	Model_male_7: ACCURACY ON VALID = 0.81518
# 	**************************************************
# 	Start model sex = male, fold = 8
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8305, number of negative: 32097
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016927 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4932
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205559 -> initscore=-1.351905
# [LightGBM] [Info] Start training from score -1.351905
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	val_set's auc: 0.757249
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Embarked processing...
# Fare processing...
# Age processing...
# Cabin processing...
# preds processing...
# Parch processing...
# Ticket1 processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# Ticket2_Cabin processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Embarked_Parch processing...
# Ticket1_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5023308981582049
# Feature Counter_FirstName removed due to low AUC value 0.500955855703061
# Feature Counter_Surname removed due to low AUC value 0.500606002098198
# Feature Embarked removed due to high VIF value = 25.821872614043155
# Feature Cabin removed due to high VIF value = 23.81181019310417
# Features ['Ticket1_Cabin']: aucs = [0.6511017734994249] was removed due to corr = [0.9281447111325767] with feat Ticket2_Cabin: auc = 0.6678882400663119
# C parameter range in [6.730607437321219e-05:0.6730607437321219], 20 values
# Result(score=0.7557008261978249, reg_alpha=0.008576644695965899, is_neg=True, min_weights=preds              -0.787446
# Cabin_Embarked     -0.173892
# Pclass             -0.031303
# Cabin_Parch        -0.009630
# Ticket2_Cabin      -0.074962
# Ticket2_Embarked    0.000000
# Fare               -0.023401
# Embarked_Parch     -0.075269
# Ticket1_Embarked    0.000000
# Ticket2_Parch      -0.212130
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Ticket1             0.000000
# FamilySize          0.000000
# Age                 0.000000
# Parch               0.000000
# SibSp               0.000000
# dtype: float64)
# preds            -0.749900
# Cabin_Embarked   -0.157000
# Pclass           -0.024043
# Ticket2_Cabin    -0.058947
# Fare             -0.014780
# Embarked_Parch   -0.066483
# Ticket2_Parch    -0.204669
# dtype: float64
# 	Model_male_8: ACCURACY ON TRAIN = 0.81587
# 	Model_male_8: ACCURACY ON VALID = 0.81002
# 	**************************************************
# 	Start model sex = male, fold = 9
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8312, number of negative: 32090
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007292 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4948
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205732 -> initscore=-1.350844
# [LightGBM] [Info] Start training from score -1.350844
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	val_set's auc: 0.778407
#  features ['Cabin'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Embarked processing...
# Age processing...
# Ticket1 processing...
# Parch processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5008497649178262
# Feature Counter_FirstName removed due to low AUC value 0.49979711338171695
# Feature Counter_Surname removed due to low AUC value 0.5014300277942338
# Feature Embarked removed due to high VIF value = 20.738624575822605
# C parameter range in [6.730607437321219e-05:0.6730607437321219], 20 values
# Result(score=0.7580878163659903, reg_alpha=0.008576644695965899, is_neg=True, min_weights=preds              -0.758974
# Cabin_Embarked     -0.040730
# Pclass             -0.041667
# Cabin_Parch        -0.019777
# Ticket2_Cabin      -0.229990
# Fare                0.000000
# Embarked_Parch     -0.166169
# Ticket2_Embarked   -0.020640
# Ticket1_Cabin       0.000000
# Ticket1_Embarked   -0.048737
# Ticket2_Parch      -0.098334
# Ticket1_Parch       0.000000
# Ticket2             0.000000
# Ticket1             0.000000
# FamilySize          0.000000
# Age                 0.000000
# Parch               0.000000
# SibSp               0.000000
# dtype: float64)
# preds              -0.734543
# Cabin_Embarked     -0.025657
# Pclass             -0.035891
# Cabin_Parch        -0.006787
# Ticket2_Cabin      -0.218459
# Embarked_Parch     -0.157605
# Ticket1_Embarked   -0.028264
# Ticket2_Parch      -0.093412
# dtype: float64
# 	Model_male_9: ACCURACY ON TRAIN = 0.81401
# 	Model_male_9: ACCURACY ON VALID = 0.81982
# 	**************************************************
# ACCURACY ON OOF = 0.81507
# ==================================================
# ==================================================
# ==================================================
# Start model for sex = female
# 	Start model sex = female, fold = 0
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22532, number of negative: 9065
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005891 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4469
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.713106 -> initscore=0.910516
# [LightGBM] [Info] Start training from score 0.910516
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	val_set's auc: 0.740932
#  features ['Parch', 'Cabin', 'Counter_Name'] have low importance
# Pclass processing...
# SibSp processing...
# Embarked processing...
# Ticket1 processing...
# Age processing...
# Fare processing...
# preds processing...
# Ticket2 processing...
# FamilySize processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# Cabin_Parch processing...
# FirstName processing...
# Counter_Surname processing...
# Ticket1_Parch processing...
# Ticket2_Cabin processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.4994964922254228
# Feature Counter_FirstName removed due to low AUC value 0.5007549321860354
# Feature Counter_Surname removed due to low AUC value 0.496851521158054
# Feature Ticket1_Cabin removed due to high VIF value = 54.512524348536544
# Feature Ticket1_Embarked removed due to high VIF value = 31.616404215403477
# Feature Embarked removed due to high VIF value = 21.029557457766632
# Features ['Ticket1_Parch']: aucs = [0.5820808567290998] was removed due to corr = [0.931193257020893] with feat Ticket2_Parch: auc = 0.5904723781486108
# Features ['Ticket1']: aucs = [0.5471721226896038] was removed due to corr = [0.9182502515623514] with feat Ticket2: auc = 0.5565397279676405
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7302966842715967, reg_alpha=0.02476674942982572, is_neg=True, min_weights=preds              -0.620457
# Cabin_Embarked     -0.338203
# Embarked_Parch     -0.061945
# Ticket2_Cabin      -0.112810
# Cabin_Parch         0.000000
# Ticket2_Embarked   -0.080819
# Pclass             -0.115097
# Ticket2_Parch      -0.152192
# Fare               -0.214972
# FamilySize         -0.033487
# SibSp              -0.217195
# Ticket2             0.000000
# Age                -0.064190
# dtype: float64)
# preds              -0.589159
# Cabin_Embarked     -0.327008
# Embarked_Parch     -0.043352
# Ticket2_Cabin      -0.085872
# Ticket2_Embarked   -0.066723
# Pclass             -0.100984
# Ticket2_Parch      -0.129113
# Fare               -0.204590
# SibSp              -0.218283
# Age                -0.031334
# dtype: float64
# 	Model_female_0: ACCURACY ON TRAIN = 0.73649
# 	Model_female_0: ACCURACY ON VALID = 0.72408
# 	**************************************************
# 	Start model sex = female, fold = 1
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22472, number of negative: 9125
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005506 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4465
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711207 -> initscore=0.901252
# [LightGBM] [Info] Start training from score 0.901252
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	val_set's auc: 0.738453
#  features ['Cabin', 'Ticket2'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Age processing...
# Ticket1 processing...
# Embarked processing...
# Parch processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Counter_FirstName processing...
# FirstName processing...
# Ticket1_Cabin processing...
# Cabin_Parch processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# Ticket1_Embarked processing...
# Ticket2_Parch processing...
# Embarked_Parch processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature Counter_Name removed due to single WOE value
# Feature FirstName removed due to low AUC value 0.49907163704597746
# Feature Counter_FirstName removed due to low AUC value 0.4998648446422149
# Feature Ticket1_Cabin removed due to high VIF value = 43.61330278878015
# Feature Ticket1_Embarked removed due to high VIF value = 31.76811763341167
# Feature Embarked removed due to high VIF value = 26.12681986004086
# Features ['Ticket1_Parch']: aucs = [0.5804968946481389] was removed due to corr = [0.911149813948542] with feat Ticket2_Parch: auc = 0.5856767840480681
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7291670010867752, reg_alpha=0.04021567162946652, is_neg=True, min_weights=preds              -0.570170
# Cabin_Embarked     -0.358543
# Embarked_Parch     -0.105493
# Ticket2_Cabin      -0.107548
# Cabin_Parch         0.000000
# Ticket2_Embarked    0.000000
# Pclass             -0.139924
# Fare               -0.264275
# Ticket2_Parch       0.000000
# FamilySize          0.000000
# SibSp              -0.340987
# Age                -0.022947
# Ticket1            -0.307851
# Parch              -0.174824
# Counter_Surname     0.000000
# dtype: float64)
# preds            -0.544518
# Cabin_Embarked   -0.345038
# Embarked_Parch   -0.089909
# Ticket2_Cabin    -0.082855
# Pclass           -0.129935
# Fare             -0.249610
# SibSp            -0.318880
# Ticket1          -0.292443
# Parch            -0.157227
# dtype: float64
# 	Model_female_1: ACCURACY ON TRAIN = 0.73512
# 	Model_female_1: ACCURACY ON VALID = 0.73844
# 	**************************************************
# 	Start model sex = female, fold = 2
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22467, number of negative: 9130
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005606 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4502
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711049 -> initscore=0.900482
# [LightGBM] [Info] Start training from score 0.900482
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	val_set's auc: 0.736894
#  features ['Cabin'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Ticket1 processing...
# Age processing...
# Embarked processing...
# Parch processing...
# Ticket2 processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Ticket2_Embarked processing...
# Cabin_Embarked processing...
# Ticket1_Parch processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5004928365052674
# Feature Counter_Name removed due to low AUC value 0.4997455962525975
# Feature Counter_Surname removed due to low AUC value 0.49878263209040496
# Feature Ticket1_Embarked removed due to high VIF value = 45.612652193340516
# Feature Ticket2_Cabin removed due to high VIF value = 40.685351999032186
# Feature Embarked removed due to high VIF value = 25.414294797147075
# Features ['Ticket1_Parch']: aucs = [0.5827518397227691] was removed due to corr = [0.9127785381589903] with feat Ticket2_Parch: auc = 0.5883759171943479
# Features ['Ticket1']: aucs = [0.5498509438851694] was removed due to corr = [0.9061747904681611] with feat Ticket2: auc = 0.5585706138626902
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7289666764402507, reg_alpha=0.015252558330278693, is_neg=True, min_weights=preds               -0.676302
# Cabin_Embarked      -0.225662
# Embarked_Parch      -0.118787
# Ticket1_Cabin       -0.168142
# Cabin_Parch          0.000000
# Ticket2_Embarked    -0.072217
# Pclass              -0.067160
# Fare                -0.207698
# Ticket2_Parch       -0.101554
# FamilySize           0.000000
# Ticket2              0.000000
# SibSp               -0.152231
# Age                  0.000000
# Parch                0.000000
# Counter_FirstName    0.000000
# dtype: float64)
# preds              -0.627860
# Cabin_Embarked     -0.217531
# Embarked_Parch     -0.105326
# Ticket1_Cabin      -0.150908
# Ticket2_Embarked   -0.060093
# Pclass             -0.062779
# Fare               -0.195292
# Ticket2_Parch      -0.086704
# SibSp              -0.155789
# dtype: float64
# 	Model_female_2: ACCURACY ON TRAIN = 0.73550
# 	Model_female_2: ACCURACY ON VALID = 0.73661
# 	**************************************************
# 	Start model sex = female, fold = 3
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22523, number of negative: 9074
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012559 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4460
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.712821 -> initscore=0.909124
# [LightGBM] [Info] Start training from score 0.909124
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	val_set's auc: 0.741498
#  features ['Cabin', 'Ticket2', 'Ticket1_Parch'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Ticket1 processing...
# Parch processing...
# Embarked processing...
# Age processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# FirstName processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_Surname removed due to low AUC value 0.5015015228560257
# Feature Ticket1_Cabin removed due to high VIF value = 42.556432739796215
# Feature Ticket1_Embarked removed due to high VIF value = 28.230277090766542
# Feature Embarked removed due to high VIF value = 22.31727535059885
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7325175303319595, reg_alpha=0.02476674942982572, is_neg=True, min_weights=preds               -0.462458
# Cabin_Embarked      -0.481323
# Embarked_Parch      -0.088637
# Ticket2_Cabin       -0.064278
# Cabin_Parch          0.000000
# Ticket2_Embarked     0.000000
# Pclass              -0.249830
# Ticket2_Parch       -0.001579
# Fare                -0.289383
# FamilySize           0.000000
# SibSp               -0.386973
# Age                 -0.013971
# Ticket1             -0.395338
# Parch               -0.221939
# Counter_FirstName    0.000000
# dtype: float64)
# preds            -0.431457
# Cabin_Embarked   -0.476494
# Embarked_Parch   -0.068739
# Ticket2_Cabin    -0.044626
# Pclass           -0.240125
# Fare             -0.270760
# SibSp            -0.379361
# Age              -0.004412
# Ticket1          -0.387925
# Parch            -0.208783
# dtype: float64
# 	Model_female_3: ACCURACY ON TRAIN = 0.73590
# 	Model_female_3: ACCURACY ON VALID = 0.73411
# 	**************************************************
# 	Start model sex = female, fold = 4
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22519, number of negative: 9078
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012333 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4469
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.712694 -> initscore=0.908505
# [LightGBM] [Info] Start training from score 0.908505
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	val_set's auc: 0.735091
#  features ['Cabin', 'Ticket2'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Embarked processing...
# Parch processing...
# Ticket1 processing...
# Age processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# FirstName processing...
# Counter_FirstName processing...
# Cabin_Parch processing...
# Ticket1_Cabin processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# ...
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	val_set's auc: 0.739528
#  features ['Embarked', 'Ticket2'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Cabin processing...
# Ticket1 processing...
# Age processing...
# Parch processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Counter_FirstName processing...
# FirstName processing...
# Ticket1_Cabin processing...
# Cabin_Parch processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'preds', 'Ticket1', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.49949752437482486
# Feature Counter_Surname removed due to low AUC value 0.5006342269198792
# Feature Ticket1_Cabin removed due to high VIF value = 43.62488047108524
# Feature Ticket1_Embarked removed due to high VIF value = 30.741853877923095
# Feature Cabin removed due to high VIF value = 20.03498596076818
# Features ['Ticket1_Parch']: aucs = [0.5854629401807243] was removed due to corr = [0.932012020810327] with feat Ticket2_Parch: auc = 0.5943419125029494
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7301474007857884, reg_alpha=0.02476674942982572, is_neg=True, min_weights=preds              -0.575375
# Cabin_Embarked     -0.316523
# Embarked_Parch     -0.138168
# Ticket2_Cabin      -0.156669
# Cabin_Parch         0.000000
# Ticket2_Embarked   -0.013777
# Pclass             -0.172773
# Ticket2_Parch       0.000000
# Fare               -0.222567
# FamilySize          0.000000
# SibSp              -0.289840
# Age                 0.000000
# Ticket1            -0.267584
# Parch              -0.149434
# dtype: float64)
# preds            -0.534583
# Cabin_Embarked   -0.307003
# Embarked_Parch   -0.120619
# Ticket2_Cabin    -0.124697
# Pclass           -0.160238
# Fare             -0.211835
# SibSp            -0.279468
# Ticket1          -0.250560
# Parch            -0.141528
# dtype: float64
# 	Model_female_5: ACCURACY ON TRAIN = 0.73666
# 	Model_female_5: ACCURACY ON VALID = 0.73069
# 	**************************************************
# 	Start model sex = female, fold = 6
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22468, number of negative: 9130
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4478
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711058 -> initscore=0.900526
# [LightGBM] [Info] Start training from score 0.900526
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	val_set's auc: 0.735343
#  features ['Cabin', 'Ticket2', 'Counter_Name'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Embarked processing...
# Parch processing...
# Ticket1 processing...
# Age processing...
# FamilySize processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# Cabin_Parch processing...
# FirstName processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Ticket1_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'FamilySize', 'FirstName', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.5006361311712594
# Feature Counter_Surname removed due to low AUC value 0.5011713635694317
# Feature Ticket1_Embarked removed due to high VIF value = 44.96739139774244
# Feature Ticket1_Cabin removed due to high VIF value = 37.39910515631931
# Feature Embarked removed due to high VIF value = 25.883956372357794
# Features ['Ticket1_Parch']: aucs = [0.5847202163947736] was removed due to corr = [0.9061852164907291] with feat Ticket2_Parch: auc = 0.5889716227911665
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7296051060347604, reg_alpha=0.0247652672784535, is_neg=True, min_weights=preds              -0.505790
# Cabin_Embarked     -0.401593
# Embarked_Parch     -0.130127
# Ticket2_Cabin      -0.096013
# Cabin_Parch         0.000000
# Ticket2_Embarked   -0.011903
# Pclass             -0.221115
# Ticket2_Parch       0.000000
# Fare               -0.260521
# FamilySize          0.000000
# SibSp              -0.314722
# Age                -0.016408
# Ticket1            -0.360914
# Parch              -0.215530
# dtype: float64)
# preds            -0.469862
# Cabin_Embarked   -0.392733
# Embarked_Parch   -0.103414
# Ticket2_Cabin    -0.068991
# Pclass           -0.213328
# Fare             -0.255936
# SibSp            -0.314262
# Ticket1          -0.355242
# Parch            -0.209763
# dtype: float64
# 	Model_female_6: ACCURACY ON TRAIN = 0.73596
# 	Model_female_6: ACCURACY ON VALID = 0.73450
# 	**************************************************
# 	Start model sex = female, fold = 7
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22486, number of negative: 9112
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4437
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711627 -> initscore=0.903301
# [LightGBM] [Info] Start training from score 0.903301
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	val_set's auc: 0.738157
#  features ['Cabin', 'Counter_Name', 'Ticket1_Parch'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Age processing...
# Ticket1 processing...
# Embarked processing...
# Parch processing...
# Ticket2 processing...
# FirstName processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# FamilySize processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# Cabin_Parch processing...
# Ticket2_Parch processing...
# Ticket1_Embarked processing...
# Embarked_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'Ticket2', 'FamilySize', 'FirstName', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.5014854131281284
# Feature Counter_Surname removed due to low AUC value 0.4995650230611134
# Feature Ticket2_Cabin removed due to high VIF value = 52.958016573044816
# Feature Embarked removed due to high VIF value = 25.86068435566064
# Feature Ticket1_Embarked removed due to high VIF value = 21.398629310914867
# Features ['Ticket1']: aucs = [0.548248827070305] was removed due to corr = [0.9210658049377384] with feat Ticket2: auc = 0.5571705917302774
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7300062295529903, reg_alpha=0.0247652672784535, is_neg=True, min_weights=preds              -0.594479
# Cabin_Embarked     -0.287565
# Embarked_Parch     -0.095356
# Ticket1_Cabin      -0.153542
# Ticket2_Embarked   -0.140086
# Cabin_Parch         0.000000
# Pclass             -0.139183
# Ticket2_Parch      -0.129126
# Fare               -0.214150
# FamilySize          0.000000
# Ticket2             0.000000
# Age                -0.035749
# SibSp              -0.237302
# Parch              -0.129205
# dtype: float64)
# preds              -0.565916
# Cabin_Embarked     -0.279187
# Embarked_Parch     -0.057990
# Ticket1_Cabin      -0.138807
# Ticket2_Embarked   -0.110639
# Pclass             -0.118931
# Ticket2_Parch      -0.111393
# Fare               -0.198862
# Age                -0.019295
# SibSp              -0.232444
# Parch              -0.073148
# dtype: float64
# 	Model_female_7: ACCURACY ON TRAIN = 0.73596
# 	Model_female_7: ACCURACY ON VALID = 0.72972
# 	**************************************************
# 	Start model sex = female, fold = 8
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22439, number of negative: 9159
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4464
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.710140 -> initscore=0.896064
# [LightGBM] [Info] Start training from score 0.896064
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	val_set's auc: 0.725574
#  features ['Cabin', 'Ticket1', 'Ticket2', 'Ticket1_Embarked'] have low importance
# Pclass processing...
# SibSp processing...
# preds processing...
# Fare processing...
# Embarked processing...
# FamilySize processing...
# Parch processing...
# Age processing...
# FirstName processing...
# Counter_FirstName processing...
# Ticket1_Cabin processing...
# Cabin_Parch processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# Ticket1_Parch processing...
# Ticket2_Parch processing...
# Ticket2_Embarked processing...
# Cabin_Embarked processing...
# Embarked_Parch processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.4968493269388691
# Feature Counter_FirstName removed due to low AUC value 0.4996985637638398
# Feature Counter_Surname removed due to low AUC value 0.5013085127629211
# Feature Ticket1_Cabin removed due to high VIF value = 38.62118574914175
# Feature Embarked removed due to high VIF value = 25.57880367258696
# Features ['Ticket1_Parch']: aucs = [0.5807970390052026] was removed due to corr = [0.9084269508845093] with feat Ticket2_Parch: auc = 0.5874269092466853
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7282973676193488, reg_alpha=0.0247652672784535, is_neg=True, min_weights=preds              -0.570532
# Cabin_Embarked     -0.325698
# Embarked_Parch     -0.082833
# Ticket2_Cabin      -0.133951
# Cabin_Parch         0.000000
# Ticket2_Embarked   -0.108385
# Pclass             -0.157314
# Ticket2_Parch      -0.164424
# Fare               -0.239884
# FamilySize          0.000000
# Age                -0.058163
# SibSp              -0.281553
# Parch              -0.066648
# dtype: float64)
# preds              -0.536272
# Cabin_Embarked     -0.308273
# Embarked_Parch     -0.055861
# Ticket2_Cabin      -0.119576
# Ticket2_Embarked   -0.088333
# Pclass             -0.152390
# Ticket2_Parch      -0.134309
# Fare               -0.225012
# Age                -0.042724
# SibSp              -0.262186
# Parch              -0.047304
# dtype: float64
# 	Model_female_8: ACCURACY ON TRAIN = 0.73480
# 	Model_female_8: ACCURACY ON VALID = 0.74134
# 	**************************************************
# 	Start model sex = female, fold = 9
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22504, number of negative: 9094
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006014 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4475
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.712197 -> initscore=0.906078
# [LightGBM] [Info] Start training from score 0.906078
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	val_set's auc: 0.74324
#  features ['Cabin', 'Ticket2'] have low importance
# Pclass processing...
# SibSp processing...
# Fare processing...
# preds processing...
# Embarked processing...
# Parch processing...
# Age processing...
# Ticket1 processing...
# FamilySize processing...
# Counter_Name processing...
# Counter_Surname processing...
# Ticket2_Cabin processing...
# FirstName processing...
# Ticket1_Cabin processing...
# Counter_FirstName processing...
# Cabin_Parch processing...
# Ticket1_Parch processing...
# Cabin_Embarked processing...
# Ticket2_Embarked processing...
# Ticket2_Parch processing...
# Embarked_Parch processing...
# Ticket1_Embarked processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'preds', 'Ticket1', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname', 'Ticket1_Cabin', 'Ticket2_Cabin', 'Cabin_Parch', 'Ticket1_Parch', 'Ticket2_Parch', 'Cabin_Embarked', 'Ticket1_Embarked', 'Ticket2_Embarked', 'Embarked_Parch']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.49994880658669394
# Feature Counter_Surname removed due to low AUC value 0.5011992259273599
# Feature Ticket1_Cabin removed due to high VIF value = 46.24227932775227
# Feature Ticket1_Embarked removed due to high VIF value = 34.21144388107669
# Feature Embarked removed due to high VIF value = 24.763028861727296
# Features ['Ticket1_Parch']: aucs = [0.5814091833157529] was removed due to corr = [0.9489763208367495] with feat Ticket2_Parch: auc = 0.5878118419930366
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7303095042683149, reg_alpha=0.0247652672784535, is_neg=True, min_weights=preds              -0.515230
# Cabin_Embarked     -0.406559
# Embarked_Parch     -0.124977
# Ticket2_Cabin      -0.073278
# Cabin_Parch         0.000000
# Ticket2_Embarked   -0.008420
# Pclass             -0.194905
# Ticket2_Parch      -0.106312
# Fare               -0.241068
# FamilySize          0.000000
# Age                -0.037243
# SibSp              -0.290657
# Ticket1            -0.287126
# Parch              -0.153120
# dtype: float64)
# preds            -0.489663
# Cabin_Embarked   -0.388829
# Embarked_Parch   -0.108761
# Ticket2_Cabin    -0.059508
# Pclass           -0.193352
# Ticket2_Parch    -0.068378
# Fare             -0.230799
# Age              -0.027993
# SibSp            -0.270491
# Ticket1          -0.277428
# Parch            -0.137548
# dtype: float64
# 	Model_female_9: ACCURACY ON TRAIN = 0.73594
# 	Model_female_9: ACCURACY ON VALID = 0.73541
# 	**************************************************
# ACCURACY ON OOF = 0.73440
# CPU times: user 29min 55s, sys: 35.9 s, total: 30min 31s
# Wall time: 1h 51min 1s

# %%
print('ACCURACY = {:.5f}'.format(accuracy_score(train_data[TARGET], (oof_preds_1 > 0.5).astype(int))))
# Out:
# ACCURACY = 0.77967

# %%
# %%time

gen_feats = create_extra_features_2(all_df)
train_data, test_data = gen_feats[:len(train_data)], gen_feats[len(train_data):]
print(train_data.shape, test_data.shape)
oof_preds_2, test_preds_2 = build_model_split_by_sex(train_data, test_data, 10)
# Out:
# (100000, 17) (100000, 17)
# ==================================================
# Start model for sex = male
# 	Start model sex = male, fold = 0
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8291, number of negative: 32110
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4093
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205218 -> initscore=-1.353997
# [LightGBM] [Info] Start training from score -1.353997
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	val_set's auc: 0.77031
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.500636476416736
# Feature Counter_Name removed due to low AUC value 0.5006640904785302
# Feature Counter_FirstName removed due to low AUC value 0.5011708760422806
# Feature Counter_Surname removed due to low AUC value 0.5020002754593224
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.7551417357885939, reg_alpha=0.013926087502455175, is_neg=True, min_weights=preds        -0.844485
# Pclass        0.000000
# Fare         -0.045840
# Cabin        -0.133641
# Embarked     -0.168104
# Ticket       -0.102020
# Age           0.000000
# FamilySize    0.000000
# Parch        -0.049921
# SibSp         0.000000
# dtype: float64)
# preds      -0.823793
# Fare       -0.036444
# Cabin      -0.121894
# Embarked   -0.152270
# Ticket     -0.102736
# Parch      -0.040375
# dtype: float64
# 	Model_male_0: ACCURACY ON TRAIN = 0.81621
# 	Model_male_0: ACCURACY ON VALID = 0.80845
# 	**************************************************
# 	Start model sex = male, fold = 1
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8344, number of negative: 32057
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4085
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206530 -> initscore=-1.345973
# [LightGBM] [Info] Start training from score -1.345973
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	val_set's auc: 0.765915
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5005406476338795
# Feature Counter_FirstName removed due to low AUC value 0.5002147004699407
# Feature Counter_Surname removed due to low AUC value 0.5032551667628449
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.7540704832865398, reg_alpha=0.008576356075535963, is_neg=True, min_weights=preds        -0.924135
# Pclass        0.000000
# Fare          0.000000
# Cabin        -0.050831
# Embarked     -0.110489
# Ticket       -0.053340
# Age           0.000000
# FamilySize    0.000000
# Parch         0.000000
# SibSp         0.000000
# dtype: float64)
# preds      -0.905390
# Cabin      -0.046388
# Embarked   -0.101573
# Ticket     -0.043667
# dtype: float64
# 	Model_male_1: ACCURACY ON TRAIN = 0.81529
# 	Model_male_1: ACCURACY ON VALID = 0.81575
# 	**************************************************
# 	Start model sex = male, fold = 2
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8325, number of negative: 32076
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4051
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206059 -> initscore=-1.348845
# [LightGBM] [Info] Start training from score -1.348845
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	val_set's auc: 0.766384
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Age processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5004271471468958
# Feature Counter_Name removed due to low AUC value 0.5017172031385264
# Feature Counter_FirstName removed due to low AUC value 0.5009743714422652
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.7562338593238406, reg_alpha=0.008576356075535963, is_neg=True, min_weights=preds             -0.903779
# Pclass             0.000000
# Fare               0.000000
# Cabin             -0.072237
# Embarked          -0.115675
# Ticket            -0.100976
# Age                0.000000
# FamilySize         0.000000
# Parch              0.000000
# SibSp              0.000000
# Counter_Surname    0.000000
# dtype: float64)
# preds      -0.885860
# Cabin      -0.065287
# Embarked   -0.106754
# Ticket     -0.091089
# dtype: float64
# 	Model_male_2: ACCURACY ON TRAIN = 0.81446
# 	Model_male_2: ACCURACY ON VALID = 0.81272
# 	**************************************************
# 	Start model sex = male, fold = 3
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8299, number of negative: 32102
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008279 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4081
# [LightGBM] [Info] Number of data points in the train set: 40401, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205416 -> initscore=-1.352783
# [LightGBM] [Info] Start training from score -1.352783
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	val_set's auc: 0.775518
#  features ['Counter_Name'] have low importance
# Pclass processing...
# Age processing...
# Parch processing...
# SibSp processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.4998437494141368
# Feature Counter_FirstName removed due to low AUC value 0.5011833036894985
# Feature Counter_Surname removed due to low AUC value 0.5006902256011274
# C parameter range in [6.730380939561179e-05:0.6730380939561179], 20 values
# Result(score=0.756350292122463, reg_alpha=0.008576356075535963, is_neg=True, min_weights=preds        -0.922145
# Pclass        0.000000
# Fare          0.000000
# Cabin        -0.051015
# Embarked     -0.103503
# Ticket       -0.057153
# Age           0.000000
# FamilySize    0.000000
# Parch         0.000000
# SibSp         0.000000
# dtype: float64)
# preds      -0.907756
# Cabin      -0.044268
# Embarked   -0.097090
# Ticket     -0.049763
# dtype: float64
# 	Model_male_3: ACCURACY ON TRAIN = 0.81593
# 	Model_male_3: ACCURACY ON VALID = 0.80969
# 	**************************************************
# 	Start model sex = male, fold = 4
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8314, number of negative: 32088
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006592 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4102
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205782 -> initscore=-1.350541
# [LightGBM] [Info] Start training from score -1.350541
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	val_set's auc: 0.76831
#  features [] have low importance
# Pclass processing...
# Age processing...
# Parch processing...
# SibSp processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.500824814891925
# Feature Counter_FirstName removed due to low AUC value 0.5001996218280034
# Feature Counter_Surname removed due to low AUC value 0.5009170441825728
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.7529391327178163, reg_alpha=0.013925618878855808, is_neg=True, min_weights=preds        -0.850936
# Pclass        0.000000
# Fare         -0.058081
# Cabin        -0.117795
# Embarked     -0.172309
# Ticket       -0.082366
# Age           0.000000
# FamilySize    0.000000
# Parch        -0.020957
# SibSp         0.000000
# dtype: float64)
# preds      -0.827417
# Fare       -0.047670
# Cabin      -0.109538
# Embarked   -0.163665
# Ticket     -0.077147
# Parch      -0.015217
# dtype: float64
# 	Model_male_4: ACCURACY ON TRAIN = 0.81490
# 	Model_male_4: ACCURACY ON VALID = 0.81893
# 	**************************************************
# 	Start model sex = male, fold = 5
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8323, number of negative: 32079
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005411 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4074
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206005 -> initscore=-1.349179
# [LightGBM] [Info] Start training from score -1.349179
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	val_set's auc: 0.767858
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5000689578689873
# Feature Counter_Name removed due to low AUC value 0.501254545765526
# Feature Counter_FirstName removed due to low AUC value 0.5002679847776452
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.755394085990335, reg_alpha=0.00857606747453063, is_neg=True, min_weights=preds             -0.920104
# Pclass            -0.000066
# Fare               0.000000
# Cabin             -0.071533
# Embarked          -0.101613
# Ticket            -0.033588
# Age                0.000000
# FamilySize         0.000000
# Parch              0.000000
# SibSp              0.000000
# Counter_Surname    0.000000
# dtype: float64)
# preds      -0.905580
# Cabin      -0.060147
# Embarked   -0.096866
# Ticket     -0.022320
# dtype: float64
# 	Model_male_5: ACCURACY ON TRAIN = 0.81528
# 	Model_male_5: ACCURACY ON VALID = 0.81643
# 	**************************************************
# 	Start model sex = male, fold = 6
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8287, number of negative: 32115
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005189 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4111
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205114 -> initscore=-1.354635
# [LightGBM] [Info] Start training from score -1.354635
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	val_set's auc: 0.765081
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Age processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5000040408937003
# Feature Counter_Name removed due to low AUC value 0.5037790860086173
# Feature Counter_FirstName removed due to low AUC value 0.5009719554780594
# Feature Counter_Surname removed due to low AUC value 0.5043939123630549
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.754244019594944, reg_alpha=0.00857606747453063, is_neg=True, min_weights=preds        -0.906879
# Pclass        0.000000
# Fare          0.000000
# Cabin        -0.066350
# Embarked     -0.102834
# Ticket       -0.073516
# Age           0.000000
# FamilySize    0.000000
# Parch         0.000000
# SibSp         0.000000
# dtype: float64)
# preds      -0.895481
# Cabin      -0.062052
# Embarked   -0.097269
# Ticket     -0.066208
# dtype: float64
# 	Model_male_6: ACCURACY ON TRAIN = 0.81449
# 	Model_male_6: ACCURACY ON VALID = 0.82285
# 	**************************************************
# 	Start model sex = male, fold = 7
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8313, number of negative: 32089
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010439 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4083
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205757 -> initscore=-1.350693
# [LightGBM] [Info] Start training from score -1.350693
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	val_set's auc: 0.767172
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5036654300260544
# Feature Counter_FirstName removed due to low AUC value 0.5008428939630871
# C parameter range in [6.73015445704479e-05:0.673015445704479], 20 values
# Result(score=0.7563352130248097, reg_alpha=0.00857606747453063, is_neg=True, min_weights=preds             -0.919336
# Pclass            -0.013206
# Fare               0.000000
# Cabin             -0.058322
# Embarked          -0.105650
# Ticket            -0.042860
# Age                0.000000
# FamilySize         0.000000
# Parch              0.000000
# SibSp              0.000000
# Counter_Surname    0.000000
# dtype: float64)
# preds      -0.901225
# Pclass     -0.005518
# Cabin      -0.053825
# Embarked   -0.100769
# Ticket     -0.036605
# dtype: float64
# 	Model_male_7: ACCURACY ON TRAIN = 0.81552
# 	Model_male_7: ACCURACY ON VALID = 0.81518
# 	**************************************************
# 	Start model sex = male, fold = 8
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8305, number of negative: 32097
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4069
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205559 -> initscore=-1.351905
# [LightGBM] [Info] Start training from score -1.351905
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	val_set's auc: 0.749238
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Age processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5023308981582049
# Feature Counter_FirstName removed due to low AUC value 0.500955855703061
# Feature Counter_Surname removed due to low AUC value 0.500606002098198
# C parameter range in [6.730607437321219e-05:0.6730607437321219], 20 values
# Result(score=0.7523652955988043, reg_alpha=0.008576644695965899, is_neg=True, min_weights=preds        -0.922695
# Pclass        0.000000
# Fare         -0.025049
# Cabin        -0.059133
# Embarked     -0.106718
# Ticket       -0.065948
# FamilySize    0.000000
# Age           0.000000
# Parch         0.000000
# SibSp         0.000000
# dtype: float64)
# preds      -0.895054
# Fare       -0.016705
# Cabin      -0.047875
# Embarked   -0.099448
# Ticket     -0.063538
# dtype: float64
# 	Model_male_8: ACCURACY ON TRAIN = 0.81585
# 	Model_male_8: ACCURACY ON VALID = 0.80984
# 	**************************************************
# 	Start model sex = male, fold = 9
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 8312, number of negative: 32090
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004939 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4091
# [LightGBM] [Info] Number of data points in the train set: 40402, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205732 -> initscore=-1.350844
# [LightGBM] [Info] Start training from score -1.350844
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [21]	val_set's auc: 0.772512
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.5008497649178262
# Feature Counter_FirstName removed due to low AUC value 0.49979711338171695
# Feature Counter_Surname removed due to low AUC value 0.5014300277942338
# C parameter range in [6.730607437321219e-05:0.6730607437321219], 20 values
# Result(score=0.7554545227545645, reg_alpha=0.008576644695965899, is_neg=True, min_weights=preds        -0.913741
# Pclass        0.000000
# Fare          0.000000
# Cabin        -0.070762
# Embarked     -0.099552
# Ticket       -0.084366
# FamilySize    0.000000
# Age           0.000000
# Parch         0.000000
# SibSp         0.000000
# dtype: float64)
# preds      -0.896458
# Cabin      -0.060057
# Embarked   -0.093053
# Ticket     -0.083095
# dtype: float64
# 	Model_male_9: ACCURACY ON TRAIN = 0.81371
# 	Model_male_9: ACCURACY ON VALID = 0.81964
# 	**************************************************
# ACCURACY ON OOF = 0.81495
# ==================================================
# ==================================================
# ==================================================
# Start model for sex = female
# 	Start model sex = female, fold = 0
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22532, number of negative: 9065
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011605 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3482
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.713106 -> initscore=0.910516
# [LightGBM] [Info] Start training from score 0.910516
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	val_set's auc: 0.738835
#  features [] have low importance
# Pclass processing...
# Age processing...
# Parch processing...
# SibSp processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature Counter_Name removed due to single WOE value
# Feature FirstName removed due to low AUC value 0.4994964922254228
# Feature Counter_FirstName removed due to low AUC value 0.5007549321860354
# Feature Counter_Surname removed due to low AUC value 0.496851521158054
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7281807236024128, reg_alpha=0.06530127214277952, is_neg=True, min_weights=preds        -0.689210
# Cabin        -0.290022
# Embarked     -0.287770
# Pclass       -0.077882
# Fare         -0.239246
# FamilySize    0.000000
# SibSp        -0.252117
# Age          -0.083924
# Ticket       -0.279537
# Parch        -0.207756
# dtype: float64)
# preds      -0.658247
# Cabin      -0.265887
# Embarked   -0.274357
# Pclass     -0.060007
# Fare       -0.220521
# SibSp      -0.237358
# Age        -0.047546
# Ticket     -0.272932
# Parch      -0.184689
# dtype: float64
# 	Model_female_0: ACCURACY ON TRAIN = 0.73601
# 	Model_female_0: ACCURACY ON VALID = 0.72477
# 	**************************************************
# 	Start model sex = female, fold = 1
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22472, number of negative: 9125
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010389 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3478
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711207 -> initscore=0.901252
# [LightGBM] [Info] Start training from score 0.901252
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	val_set's auc: 0.737411
#  features ['Counter_Name'] have low importance
# Pclass processing...
# Age processing...
# Parch processing...
# SibSp processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.49907163704597746
# Feature Counter_FirstName removed due to low AUC value 0.4998648446422149
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7269901922644101, reg_alpha=0.04021567162946652, is_neg=True, min_weights=preds             -0.740686
# Cabin             -0.249123
# Embarked          -0.239431
# Pclass            -0.027853
# Fare              -0.221078
# FamilySize         0.000000
# SibSp             -0.238781
# Age               -0.024475
# Ticket            -0.257232
# Parch             -0.166200
# Counter_Surname    0.000000
# dtype: float64)
# preds      -0.716095
# Cabin      -0.230796
# Embarked   -0.228608
# Pclass     -0.017400
# Fare       -0.206972
# SibSp      -0.218634
# Ticket     -0.248941
# Parch      -0.144477
# dtype: float64
# 	Model_female_1: ACCURACY ON TRAIN = 0.73527
# 	Model_female_1: ACCURACY ON VALID = 0.73889
# 	**************************************************
# 	Start model sex = female, fold = 2
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22467, number of negative: 9130
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3502
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711049 -> initscore=0.900482
# [LightGBM] [Info] Start training from score 0.900482
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	val_set's auc: 0.738283
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to low AUC value 0.5004928365052674
# Feature Counter_Name removed due to low AUC value 0.4997455962525975
# Feature Counter_Surname removed due to low AUC value 0.49878263209040496
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7277349185612788, reg_alpha=0.04021567162946652, is_neg=True, min_weights=preds               -0.696348
# Cabin               -0.261680
# Embarked            -0.276704
# Pclass              -0.069143
# Fare                -0.267903
# FamilySize           0.000000
# SibSp               -0.259977
# Age                  0.000000
# Ticket              -0.331674
# Parch               -0.216450
# Counter_FirstName    0.000000
# dtype: float64)
# preds      -0.662291
# Cabin      -0.250058
# Embarked   -0.261626
# Pclass     -0.054587
# Fare       -0.244508
# SibSp      -0.241069
# Ticket     -0.320079
# Parch      -0.208809
# dtype: float64
# 	Model_female_2: ACCURACY ON TRAIN = 0.73499
# 	Model_female_2: ACCURACY ON VALID = 0.73570
# 	**************************************************
# 	Start model sex = female, fold = 3
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22523, number of negative: 9074
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006670 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3477
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.712821 -> initscore=0.909124
# [LightGBM] [Info] Start training from score 0.909124
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	val_set's auc: 0.738587
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_Surname removed due to low AUC value 0.5015015228560257
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7283125888063091, reg_alpha=0.06530127214277952, is_neg=True, min_weights=preds               -0.625076
# Cabin               -0.317598
# Embarked            -0.287812
# Pclass              -0.140024
# Fare                -0.267840
# FamilySize           0.000000
# SibSp               -0.348796
# Age                 -0.022230
# Ticket              -0.351608
# Parch               -0.237484
# Counter_FirstName    0.000000
# dtype: float64)
# preds      -0.600728
# Cabin      -0.300719
# Embarked   -0.277521
# Pclass     -0.122092
# Fare       -0.244069
# SibSp      -0.328672
# Age        -0.008860
# Ticket     -0.336899
# Parch      -0.208643
# dtype: float64
# 	Model_female_3: ACCURACY ON TRAIN = 0.73494
# 	Model_female_3: ACCURACY ON VALID = 0.73388
# 	**************************************************
# 	Start model sex = female, fold = 4
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22519, number of negative: 9078
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006397 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3482
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.712694 -> initscore=0.908505
# [LightGBM] [Info] Start training from score 0.908505
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	val_set's auc: 0.73259
#  features [] have low importance
# Pclass processing...
# Age processing...
# Parch processing...
# SibSp processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.501825670859167
# Feature Counter_Surname removed due to low AUC value 0.5017537935987637
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.7266876048791343, reg_alpha=0.04021567162946652, is_neg=True, min_weights=preds        -0.708303
# Cabin        -0.264839
# Embarked     -0.250444
# Pclass       -0.063799
# Fare         -0.206529
# FamilySize    0.000000
# SibSp        -0.213149
# Age          -0.063791
# Ticket       -0.294625
# Parch        -0.211501
# dtype: float64)
# preds      -0.682764
# Cabin      -0.244595
# Embarked   -0.245535
# Pclass     -0.051945
# Fare       -0.189342
# SibSp      -0.207881
# Age        -0.030518
# Ticket     -0.287698
# Parch      -0.190269
# dtype: float64
# 	Model_female_4: ACCURACY ON TRAIN = 0.73388
# 	Model_female_4: ACCURACY ON VALID = 0.74094
# 	**************************************************
# 	Start model sex = female, fold = 5
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22476, number of negative: 9121
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003963 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3481
# [LightGBM] [Info] Number of data points in the train set: 31597, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711333 -> initscore=0.901869
# [LightGBM] [Info] Start training from score 0.901869
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	val_set's auc: 0.735879
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.49949752437482486
# Feature Counter_Surname removed due to low AUC value 0.5006342269198792
# C parameter range in [0.00011969597223053444:1.1969597223053443], 20 values
# Result(score=0.727933150493044, reg_alpha=0.04021567162946652, is_neg=True, min_weights=preds        -0.693202
# Cabin        -0.273468
# Embarked     -0.267854
# Pclass       -0.107642
# Fare         -0.213568
# FamilySize    0.000000
# SibSp        -0.259215
# Age          -0.010630
# Ticket       -0.287990
# Parch        -0.225815
# dtype: float64)
# preds      -0.660165
# Cabin      -0.261181
# Embarked   -0.252012
# Pclass     -0.088734
# Fare       -0.196952
# SibSp      -0.243519
# Ticket     -0.273905
# Parch      -0.208113
# dtype: float64
# 	Model_female_5: ACCURACY ON TRAIN = 0.73590
# 	Model_female_5: ACCURACY ON VALID = 0.73183
# 	**************************************************
# 	Start model sex = female, fold = 6
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22468, number of negative: 9130
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004273 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3498
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711058 -> initscore=0.900526
# [LightGBM] [Info] Start training from score 0.900526
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	val_set's auc: 0.733007
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.5006361311712594
# Feature Counter_Surname removed due to low AUC value 0.5011713635694317
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7271886052419873, reg_alpha=0.06529736422703189, is_neg=True, min_weights=preds        -0.598567
# Cabin        -0.313524
# Embarked     -0.312991
# Pclass       -0.163180
# Fare         -0.270255
# FamilySize    0.000000
# SibSp        -0.316808
# Age          -0.042596
# Ticket       -0.391015
# Parch        -0.298865
# dtype: float64)
# preds      -0.575884
# Cabin      -0.300673
# Embarked   -0.298433
# Pclass     -0.150360
# Fare       -0.254931
# SibSp      -0.306679
# Age        -0.012770
# Ticket     -0.358696
# Parch      -0.293228
# dtype: float64
# 	Model_female_6: ACCURACY ON TRAIN = 0.73533
# 	Model_female_6: ACCURACY ON VALID = 0.73314
# 	**************************************************
# 	Start model sex = female, fold = 7
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22486, number of negative: 9112
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004333 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3453
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.711627 -> initscore=0.903301
# [LightGBM] [Info] Start training from score 0.903301
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	val_set's auc: 0.734114
#  features [] have low importance
# Pclass processing...
# Age processing...
# SibSp processing...
# Parch processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.5014854131281284
# Feature Counter_Surname removed due to low AUC value 0.4995650230611134
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7280577034475773, reg_alpha=0.06529736422703189, is_neg=True, min_weights=preds        -0.684442
# Cabin        -0.294160
# Embarked     -0.290355
# Pclass       -0.088802
# Fare         -0.229100
# FamilySize    0.000000
# Age          -0.063066
# SibSp        -0.268580
# Ticket       -0.339182
# Parch        -0.251052
# dtype: float64)
# preds      -0.652429
# Cabin      -0.268474
# Embarked   -0.269187
# Pclass     -0.064674
# Fare       -0.206762
# Age        -0.041875
# SibSp      -0.250454
# Ticket     -0.307045
# Parch      -0.218339
# dtype: float64
# 	Model_female_7: ACCURACY ON TRAIN = 0.73540
# 	Model_female_7: ACCURACY ON VALID = 0.73154
# 	**************************************************
# 	Start model sex = female, fold = 8
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22439, number of negative: 9159
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003958 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3479
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.710140 -> initscore=0.896064
# [LightGBM] [Info] Start training from score 0.896064
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	val_set's auc: 0.723365
#  features [] have low importance
# Pclass processing...
# SibSp processing...
# Parch processing...
# Age processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to low AUC value 0.4968493269388691
# Feature Counter_FirstName removed due to low AUC value 0.4996985637638398
# Feature Counter_Surname removed due to low AUC value 0.5013085127629211
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7265063052698733, reg_alpha=0.06529736422703189, is_neg=True, min_weights=preds        -0.640061
# Cabin        -0.303352
# Embarked     -0.290641
# Pclass       -0.121690
# Fare         -0.254318
# FamilySize    0.000000
# Age          -0.083106
# SibSp        -0.320445
# Ticket       -0.328619
# Parch        -0.232583
# dtype: float64)
# preds      -0.612020
# Cabin      -0.285010
# Embarked   -0.278576
# Pclass     -0.112198
# Fare       -0.234322
# Age        -0.064617
# SibSp      -0.292794
# Ticket     -0.322234
# Parch      -0.211289
# dtype: float64
# 	Model_female_8: ACCURACY ON TRAIN = 0.73416
# 	Model_female_8: ACCURACY ON VALID = 0.73997
# 	**************************************************
# 	Start model sex = female, fold = 9
#  features ['Sex'] contain too many nans or identical values
# [LightGBM] [Info] Number of positive: 22504, number of negative: 9094
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003999 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3482
# [LightGBM] [Info] Number of data points in the train set: 31598, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.712197 -> initscore=0.906078
# [LightGBM] [Info] Start training from score 0.906078
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	val_set's auc: 0.73983
#  features [] have low importance
# Pclass processing...
# Parch processing...
# SibSp processing...
# Age processing...
# Ticket processing...
# Fare processing...
# Cabin processing...
# Embarked processing...
# preds processing...
# FamilySize processing...
# FirstName processing...
# Counter_Name processing...
# Counter_FirstName processing...
# Counter_Surname processing...
# dict_keys(['Pclass', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'preds', 'FamilySize', 'FirstName', 'Counter_Name', 'Counter_FirstName', 'Counter_Surname']) to selector !!!!!
# Feature selection...
# Feature FirstName removed due to single WOE value
# Feature Counter_Name removed due to single WOE value
# Feature Counter_FirstName removed due to low AUC value 0.49994880658669394
# Feature Counter_Surname removed due to low AUC value 0.5011992259273599
# C parameter range in [0.00011968880909634949:1.196888090963495], 20 values
# Result(score=0.7277006564066406, reg_alpha=0.06529736422703189, is_neg=True, min_weights=preds        -0.612936
# Cabin        -0.318097
# Embarked     -0.311335
# Pclass       -0.141143
# Fare         -0.251802
# FamilySize    0.000000
# Age          -0.068821
# SibSp        -0.293135
# Ticket       -0.372265
# Parch        -0.300914
# dtype: float64)
# preds      -0.591781
# Cabin      -0.303537
# Embarked   -0.295063
# Pclass     -0.134096
# Fare       -0.231898
# Age        -0.054804
# SibSp      -0.263911
# Ticket     -0.337496
# Parch      -0.281102
# dtype: float64
# 	Model_female_9: ACCURACY ON TRAIN = 0.73563
# 	Model_female_9: ACCURACY ON VALID = 0.73177
# 	**************************************************
# ACCURACY ON OOF = 0.73424
# CPU times: user 21min 1s, sys: 28.9 s, total: 21min 30s
# Wall time: 1h 8min 19s

# %%
print('ACCURACY = {:.5f}'.format(accuracy_score(train_data[TARGET], (oof_preds_2 > 0.5).astype(int))))
# Out:
# ACCURACY = 0.77953

# %%
best_score = -1
best_w = None
for w in np.arange(0, 1.01, 0.01):
    comb_pred = w * oof_preds_1 + (1 - w) * oof_preds_2
    score = accuracy_score(train_data[TARGET], (comb_pred > 0.5).astype(int))
    
    if score > best_score:
        best_score = score
        best_w = w
    
    print('{:.2f} ACCURACY = {:.5f}'.format(w, score))
# Out:
# 0.00 ACCURACY = 0.77953
# 0.01 ACCURACY = 0.77954
# 0.02 ACCURACY = 0.77951
# 0.03 ACCURACY = 0.77954
# 0.04 ACCURACY = 0.77953
# 0.05 ACCURACY = 0.77948
# 0.06 ACCURACY = 0.77948
# 0.07 ACCURACY = 0.77958
# 0.08 ACCURACY = 0.77959
# 0.09 ACCURACY = 0.77958
# 0.10 ACCURACY = 0.77958
# 0.11 ACCURACY = 0.77960
# 0.12 ACCURACY = 0.77961
# 0.13 ACCURACY = 0.77960
# 0.14 ACCURACY = 0.77956
# 0.15 ACCURACY = 0.77957
# 0.16 ACCURACY = 0.77957
# 0.17 ACCURACY = 0.77957
# 0.18 ACCURACY = 0.77960
# 0.19 ACCURACY = 0.77959
# 0.20 ACCURACY = 0.77960
# 0.21 ACCURACY = 0.77962
# 0.22 ACCURACY = 0.77962
# 0.23 ACCURACY = 0.77963
# 0.24 ACCURACY = 0.77963
# 0.25 ACCURACY = 0.77969
# 0.26 ACCURACY = 0.77969
# 0.27 ACCURACY = 0.77969
# 0.28 ACCURACY = 0.77968
# 0.29 ACCURACY = 0.77966
# 0.30 ACCURACY = 0.77967
# 0.31 ACCURACY = 0.77967
# 0.32 ACCURACY = 0.77966
# 0.33 ACCURACY = 0.77963
# 0.34 ACCURACY = 0.77964
# 0.35 ACCURACY = 0.77961
# 0.36 ACCURACY = 0.77962
# 0.37 ACCURACY = 0.77958
# 0.38 ACCURACY = 0.77958
# 0.39 ACCURACY = 0.77955
# 0.40 ACCURACY = 0.77955
# 0.41 ACCURACY = 0.77958
# 0.42 ACCURACY = 0.77958
# 0.43 ACCURACY = 0.77955
# 0.44 ACCURACY = 0.77957
# 0.45 ACCURACY = 0.77957
# 0.46 ACCURACY = 0.77956
# 0.47 ACCURACY = 0.77957
# 0.48 ACCURACY = 0.77955
# 0.49 ACCURACY = 0.77954
# 0.50 ACCURACY = 0.77954
# 0.51 ACCURACY = 0.77954
# 0.52 ACCURACY = 0.77957
# 0.53 ACCURACY = 0.77957
# 0.54 ACCURACY = 0.77957
# 0.55 ACCURACY = 0.77958
# 0.56 ACCURACY = 0.77957
# 0.57 ACCURACY = 0.77956
# 0.58 ACCURACY = 0.77954
# 0.59 ACCURACY = 0.77953
# 0.60 ACCURACY = 0.77952
# 0.61 ACCURACY = 0.77956
# 0.62 ACCURACY = 0.77953
# 0.63 ACCURACY = 0.77952
# 0.64 ACCURACY = 0.77951
# 0.65 ACCURACY = 0.77953
# 0.66 ACCURACY = 0.77951
# 0.67 ACCURACY = 0.77948
# 0.68 ACCURACY = 0.77949
# 0.69 ACCURACY = 0.77953
# 0.70 ACCURACY = 0.77953
# 0.71 ACCURACY = 0.77957
# 0.72 ACCURACY = 0.77958
# 0.73 ACCURACY = 0.77960
# 0.74 ACCURACY = 0.77958
# 0.75 ACCURACY = 0.77954
# 0.76 ACCURACY = 0.77953
# 0.77 ACCURACY = 0.77953
# 0.78 ACCURACY = 0.77957
# 0.79 ACCURACY = 0.77957
# 0.80 ACCURACY = 0.77956
# 0.81 ACCURACY = 0.77956
# 0.82 ACCURACY = 0.77955
# 0.83 ACCURACY = 0.77954
# 0.84 ACCURACY = 0.77959
# 0.85 ACCURACY = 0.77961
# 0.86 ACCURACY = 0.77962
# 0.87 ACCURACY = 0.77965
# 0.88 ACCURACY = 0.77966
# 0.89 ACCURACY = 0.77967
# 0.90 ACCURACY = 0.77968
# 0.91 ACCURACY = 0.77968
# 0.92 ACCURACY = 0.77970
# 0.93 ACCURACY = 0.77967
# 0.94 ACCURACY = 0.77969
# 0.95 ACCURACY = 0.77970
# 0.96 ACCURACY = 0.77969
# 0.97 ACCURACY = 0.77968
# 0.98 ACCURACY = 0.77968
# 0.99 ACCURACY = 0.77966
# 1.00 ACCURACY = 0.77967

# %%
print('BEST W = {:.2f}, BEST ACCURACY = {:.5f}'.format(best_w, best_score))
# Out:
# BEST W = 0.92, BEST ACCURACY = 0.77970

# %%
preds = best_w * test_preds_1 + (1 - best_w) * test_preds_2

# %% [markdown]
# # Create submissions

# %%
bound = pd.Series(preds).sort_values(ascending = False).head(34911).values[-1]
bound
# Out:
# 0.4177912594459845

# %%
submission['Survived'] = (preds > bound).astype(int)
submission.to_csv('1_AutoWoE_submission_combo.csv', index = False)

# %%
submission['Survived'].mean()
# Out:
# 0.34876

# %% [markdown]
# # Appendix

# %%
import joblib
joblib.dump((oof_preds_1, test_preds_1, oof_preds_2, test_preds_2), 'both_preproc_preds.pkl')
# Out:
# ['both_preproc_preds.pkl']
